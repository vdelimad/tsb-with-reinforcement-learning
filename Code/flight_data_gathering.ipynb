# %% [markdown]
# Libraries

# %%
import pandas as pd
import requests
from datetime import datetime
import time
import os
import json

# %% [markdown]
# Bring in data

# %%
capital_cities = pd.read_csv('../Data/capital_cities_and_airports.csv')

display(capital_cities.shape)
display(capital_cities.head())
# Out:
# (45, 6)
#        country capital_city  capital_latitude  capital_longitude airport_iata  \
# 0  Afghanistan        Kabul           34.5167            69.1833          KBL
# 1      Armenia      Yerevan           40.1812            44.5136          EVN
# 2   Azerbaijan         Baku           40.3953            49.8622          GYD
# 3      Bahrain       Manama           26.2361            50.5831          BAH
# 4   Bangladesh        Dhaka           23.7231            90.4086          DAC
#
#                              airport_name
# 0      Hamid Karzai International Airport
# 1        Zvartnots International Airport
# 2     Heydar Aliyev International Airport
# 3           Bahrain International Airport
# 4  Hazrat Shahjalal International Airport

# %% [markdown]
# Helper functions

# %%
# format departure datetime
def combine_to_datetime(dataframe, direction):
    # combine the departure columns into a single datetime column
    dataframe[f'{direction}_datetime'] = pd.to_datetime(
        dataframe[f'{direction}_year'].astype(str) + '-' +
        dataframe[f'{direction}_month'].astype(str).str.zfill(2) + '-' +
        dataframe[f'{direction}_day'].astype(str).str.zfill(2) + ' ' +
        dataframe[f'{direction}_hour'].astype(str).str.zfill(2) + ':' +
        dataframe[f'{direction}_minute'].astype(str).str.zfill(2) + ':' +
        dataframe[f'{direction}_second'].astype(str).str.zfill(2)
    )
    
    # drop the original departure columns
    dataframe.drop([f'{direction}_day', f'{direction}_month', f'{direction}_year', f'{direction}_hour', f'{direction}_minute', f'{direction}_second'], axis=1, inplace=True)

# %% [markdown]
# Get data

# %%
# bring in key
with open('../Data/skyscanner_auth.txt', 'r') as file:
    skyscanner_auth = file.read()

# %%
# set up api
def get_flight_tables(departure_airport, arrival_airport, year, month, day, skyscanner_auth=skyscanner_auth):
    url = 'https://partners.api.skyscanner.net/apiservices/v3/flights/live/search/create'
    headers = {'x-api-key': skyscanner_auth}

    data = {
        'query': {
            'market': 'US',
            'locale': 'en-US',
            'currency': 'USD',
            'query_legs': [{
                'origin_place_id': {'iata': departure_airport},
                'destination_place_id': {'iata': arrival_airport},
                'date': {'year': year, 'month': month, 'day': day}
            }],
            'adults': 1,
            'cabin_class': 'CABIN_CLASS_ECONOMY'
        }
    }
    
    try:
        response = requests.post(url, headers=headers, json=data)
        
        if response.status_code == 200:
            # store data
            response = response.json()
            #print(json.dumps(response, indent=4)

            return response['content']['results']
        else:
            response.raise_for_status()
    except requests.exceptions.HTTPError as err:
        print(err)

# test
flight_tables = get_flight_tables('NRT', 'TLV', 2023, 5, 22)

# %% [markdown]
# * Itineraries:	Bookable itinerary which corresponds with what was requested in the search. A return trip will consist of 2 legs, while a one-way trip will consist of 1 leg. An itinerary will contain a deepLink field which takes the traveler to the booking page.
# * Leg:	Includes details about the flight leg from destination to origin. A leg has 1 segment if it is a direct flight, and can have multiple segments if there are multiple stopovers.
# * Segment:	Shows the individual stops in a leg. I.e.: if a leg has 1 stop, the segment will show details about the stopover such as the length of time and where the stopover location is.
# * Places:	Shows the individual stops in a leg. I.e.: if a leg has 1 stop, the segment will show details about the stopover such as the length of time and where the stopover location is.
# * Carriers:	Similar to places, carriers contains information about the airlines referenced in itineraries.
# * Agents:	similar to places, agents contains information about the OTAs referenced in itineraries.
#
# https://developers.skyscanner.net/docs/flights-live-prices/overview

# %% [markdown]
# ### Itineraries

# %%
def clean_itineraries_table(flight_tables):
    
    # subset
    itineraries_dict = flight_tables['itineraries']
    # check if no itineraries
    if not itineraries_dict:
        raise Exception("No itineraries!")
    

    # format
    rows = []
    for key, value in itineraries_dict.items():
        for pricing_option in value['pricingOptions']:
            price = pricing_option['price']
            for item in pricing_option['items']:
                item_price = item['price']
                for fare in item['fares']:
                    rows.append({
                        'id': key,
                        'price_amount': price['amount'],
                        'price_unit': price['unit'],
                        'price_update_status': price['updateStatus'],
                        'agent_id': item['agentId'],
                        'deep_link': item['deepLink'],
                        'segment_id': fare['segmentId'],
                        'booking_code': fare['bookingCode'],
                        'fare_basis_code': fare['fareBasisCode'],
                        'transfer_type': pricing_option['transferType'],
                        'option_id': pricing_option['id']
                    })

    # create dataframe
    return pd.DataFrame(rows)


# test
itineraries = clean_itineraries_table(flight_tables)
display(itineraries.head())
# Out:
#                                                   id price_amount  \
# 0  14788-2305220920--32128,-32301-2-16995-2305222330      1003560
# 1  14788-2305220920--32128,-32301-2-16995-2305222330      1003560
# 2  14788-2305220920--32128,-32301-2-16995-2305222330      1003560
# 3         14788-2305221035--31734-1-16995-2305222155      1039990
# 4         14788-2305221035--31734-1-16995-2305222155      1039990
#
#          price_unit              price_update_status agent_id  \
# 0  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     edus
# 1  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     edus
# 2  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     edus
# 3  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     fnus
# 4  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     fnus
#
#                                            deep_link  \
# 0  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 1  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 2  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 3  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 4  https://skyscanner.pxf.io/c/2850210/1103265/13...
#
#                                  segment_id booking_code fare_basis_code  \
# 0  14788-12409-2305220920-2305221145--32128
# 1  12409-11182-2305221330-2305221855--32128
# 2  11182-16995-2305222055-2305222330--32301
# 3  14788-12585-2305221035-2305221750--31734
# 4  12585-16995-2305221950-2305222155--31734
#
#                            transfer_type     option_id
# 0  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  BNvJtlhvqMlN
# 1  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  BNvJtlhvqMlN
# 2  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  BNvJtlhvqMlN
# 3                  TRANSFER_TYPE_MANAGED  VoKv1Wadljp0
# 4                  TRANSFER_TYPE_MANAGED  VoKv1Wadljp0

# %% [markdown]
# ### Legs

# %%
def clean_legs_table(flight_tables):
    # subset
    legs_dict = flight_tables['legs']

    # format
    rows = []
    for key, value in legs_dict.items():
        departure_dt = value['departureDateTime']
        arrival_dt = value['arrivalDateTime']
        for segment_id, marketing_carrier_id, operating_carrier_id in zip(value['segmentIds'], value['marketingCarrierIds'], value['operatingCarrierIds']):
            rows.append({
                'id': key,
                'origin_place_id': value['originPlaceId'],
                'destination_place_id': value['destinationPlaceId'],
                'departure_year': departure_dt['year'],
                'departure_month': departure_dt['month'],
                'departure_day': departure_dt['day'],
                'departure_hour': departure_dt['hour'],
                'departure_minute': departure_dt['minute'],
                'departure_second': departure_dt['second'],
                'arrival_year': arrival_dt['year'],
                'arrival_month': arrival_dt['month'],
                'arrival_day': arrival_dt['day'],
                'arrival_hour': arrival_dt['hour'],
                'arrival_minute': arrival_dt['minute'],
                'arrival_second': arrival_dt['second'],
                'duration_minutes': value['durationInMinutes'],
                'stop_count': value['stopCount'],
                'marketing_carrier_id': marketing_carrier_id,
                'operating_carrier_id': operating_carrier_id,
                'segment_id': segment_id
            })

    # create dataframe
    legs = pd.DataFrame(rows)

    # combine time  columns
    combine_to_datetime(legs, 'departure')
    combine_to_datetime(legs, 'arrival')

    # rename id column
    return legs.rename(columns={'id': 'leg_id'})


# test
legs = clean_legs_table(flight_tables)
display(legs.head(100))
# Out:
#                                                leg_id origin_place_id  \
# 0   14788-2305220915--31461,-32213,-31669-3-16995-...       128668889
# 1   14788-2305220915--31461,-32213,-31669-3-16995-...       128668889
# 2   14788-2305220915--31461,-32213,-31669-3-16995-...       128668889
# 3   14788-2305220930--31705,-32339,-31669-3-16995-...       128668889
# 4   14788-2305220930--31705,-32339,-31669-3-16995-...       128668889
# 5   14788-2305220930--31705,-32339,-31669-3-16995-...       128668889
# 6          14788-2305221035--31734-1-16995-2305222155       128668889
# 7   14788-2305221445--31461,-32352-1-16995-2305230445       128668889
# 8   14788-2305221445--31461,-32352-1-16995-2305230445       128668889
# 9   14788-2305221700--30816,-32348-2-16995-2305230935       128668889
# 10  14788-2305221700--30816,-32348-2-16995-2305230935       128668889
# 11  14788-2305221700--30816,-32352-1-16995-2305230445       128668889
# 12  14788-2305221700--30816,-32352-1-16995-2305230445       128668889
# 13         14788-2305221715--32456-1-16995-2305230745       128668889
# 14         14788-2305222115--32340-2-16995-2305231435       128668889
# 15         14788-2305222150--32093-1-16995-2305231850       128668889
# 16         14788-2305222230--32348-1-16995-2305230935       128668889
#
#    destination_place_id  duration_minutes  stop_count marketing_carrier_id  \
# 0              95673635              1895           3               -31461
# 1              95673635              1895           3               -32213
# 2              95673635              1895           3               -31669
# 3              95673635              1880           3               -31705
# 4              95673635              1880           3               -32339
# 5              95673635              1880           3               -31669
# 6              95673635              1040           1               -31734
# 7              95673635              1200           1               -31461
# 8              95673635              1200           1               -32352
# 9              95673635              1355           2               -30816
# 10             95673635              1355           2               -32348
# 11             95673635              1065           1               -30816
# 12             95673635              1065           1               -32352
# 13             95673635              1230           1               -32456
# 14             95673635              1400           2               -32340
# 15             95673635              1620           1               -32093
# 16             95673635              1025           1               -32348
#
#    operating_carrier_id                                segment_id  \
# 0                -31461   14788-9970-2305220915-2305221400--31461
# 1                -32213   9970-10075-2305221550-2305221835--32213
# 2                -32761   10075-9618-2305222215-2305222345--32213
# 3                -31705  14788-12071-2305220930-2305221305--31705
# 4                -32339  12071-10075-2305221820-2305222150--31705
# 5                -32761   10075-9618-2305230445-2305230610--32339
# 6                -31734  14788-12585-2305221035-2305221750--31734
# 7                -31461   14788-9970-2305221445-2305221935--31461
# 8                -32352   9970-16995-2305222355-2305230445--32352
# 9                -30816   14788-9970-2305221700-2305222145--30816
# 10               -32348   9970-11182-2305230115-2305230445--32348
# 11               -30816   14788-9970-2305221700-2305222145--30816
# 12               -32352   9970-16995-2305222355-2305230445--32352
# 13               -32456  14788-12191-2305221715-2305222120--32456
# 14               -32340  14788-12409-2305222115-2305222355--32340
# 15               -32093  14788-17648-2305222150-2305230540--32093
# 16               -32348  14788-11182-2305222230-2305230445--32348
#
#     departure_datetime    arrival_datetime
# 0  2023-05-22 09:15:00 2023-05-23 10:50:00
# 1  2023-05-22 09:15:00 2023-05-23 10:50:00
# 2  2023-05-22 09:15:00 2023-05-23 10:50:00
# 3  2023-05-22 09:30:00 2023-05-23 10:50:00
# 4  2023-05-22 09:30:00 2023-05-23 10:50:00
# 5  2023-05-22 09:30:00 2023-05-23 10:50:00
# 6  2023-05-22 10:35:00 2023-05-22 21:55:00
# 7  2023-05-22 14:45:00 2023-05-23 04:45:00
# 8  2023-05-22 14:45:00 2023-05-23 04:45:00
# 9  2023-05-22 17:00:00 2023-05-23 09:35:00
# 10 2023-05-22 17:00:00 2023-05-23 09:35:00
# 11 2023-05-22 17:00:00 2023-05-23 04:45:00
# 12 2023-05-22 17:00:00 2023-05-23 04:45:00
# 13 2023-05-22 17:15:00 2023-05-23 07:45:00
# 14 2023-05-22 21:15:00 2023-05-23 14:35:00
# 15 2023-05-22 21:50:00 2023-05-23 18:50:00
# 16 2023-05-22 22:30:00 2023-05-23 09:35:00

# %%
legs_test = legs['leg_id'].nunique()
legs_test
# Out:
# 10

# %% [markdown]
# ### Segments

# %%
def clean_segments_table(flight_tables):
    # subset
    segments_dict = flight_tables['segments']

    # format
    rows = []
    for key, value in segments_dict.items():
        departure_dt = value['departureDateTime']
        arrival_dt = value['arrivalDateTime']

        rows.append({
            'id': key,
            'origin_place_id': value['originPlaceId'],
            'destination_place_id': value['destinationPlaceId'],
            'departure_year': departure_dt['year'],
            'departure_month': departure_dt['month'],
            'departure_day': departure_dt['day'],
            'departure_hour': departure_dt['hour'],
            'departure_minute': departure_dt['minute'],
            'departure_second': departure_dt['second'],
            'arrival_year': arrival_dt['year'],
            'arrival_month': arrival_dt['month'],
            'arrival_day': arrival_dt['day'],
            'arrival_hour': arrival_dt['hour'],
            'arrival_minute': arrival_dt['minute'],
            'arrival_second': arrival_dt['second'],
            'duration_minutes': value['durationInMinutes'],
            'marketing_flight_number': value['marketingFlightNumber'],
            'marketing_carrier_id': value['marketingCarrierId'],
            'operating_carrier_id': value['operatingCarrierId']
        })


    # create dataframe
    segments = pd.DataFrame(rows)

    # combine time columns
    combine_to_datetime(segments, 'departure')
    combine_to_datetime(segments, 'arrival')

    # rename id column
    return segments.rename(columns={'id': 'segment_id'})


# test
segments = clean_segments_table(flight_tables)
display(segments.head(100))
# Out:
#                                   segment_id origin_place_id  \
# 0   11182-16995-2305222055-2305222330--32301        95673506
# 1   11182-16995-2305230705-2305230935--32348        95673506
# 2   12191-16995-2305230220-2305230745--32456       128668132
# 3   12409-11182-2305221330-2305221855--32128        95673659
# 4    12409-9252-2305230105-2305230705--32340        95673659
# 5   12585-16995-2305221950-2305222155--31734        95673323
# 6   14788-11182-2305222230-2305230445--32348       128668889
# 7   14788-12191-2305221715-2305222120--32456       128668889
# 8   14788-12191-2305221830-2305222225--32456       128668889
# 9   14788-12409-2305220920-2305221145--32128       128668889
# 10  14788-12409-2305222115-2305222355--32340       128668889
# 11  14788-12585-2305221035-2305221750--31734       128668889
# 12  14788-17648-2305222150-2305230540--32093       128668889
# 13   14788-9970-2305221445-2305221935--31461       128668889
# 14   14788-9970-2305221700-2305222145--30816       128668889
# 15  17648-16995-2305231400-2305231850--32093        95673438
# 16   9252-16995-2305231000-2305231435--32340       128668203
# 17   9970-11182-2305230115-2305230445--32348        95673349
# 18   9970-16995-2305222355-2305230445--32352        95673349
#
#    destination_place_id  duration_minutes marketing_flight_number  \
# 0              95673635               215                    1807
# 1              95673635               210                    2369
# 2              95673635               625                     675
# 3              95673506               625                     951
# 4             128668203               720                     673
# 5              95673635               125                     864
# 6              95673506               675                     319
# 7             128668132               305                     521
# 8             128668132               295                     505
# 9              95673659               145                     706
# 10             95673659               160                     673
# 11             95673323               795                      51
# 12             95673438               890                      80
# 13             95673349               410                     603
# 14             95673349               405                      51
# 15             95673635               230                     155
# 16             95673635               275                     418
# 17             95673506               390                     385
# 18             95673635               530                      82
#
#    marketing_carrier_id operating_carrier_id  departure_datetime  \
# 0                -32301               -32301 2023-05-22 20:55:00
# 1                -32348               -32301 2023-05-23 07:05:00
# 2                -32456               -32456 2023-05-23 02:20:00
# 3                -32128               -32128 2023-05-22 13:30:00
# 4                -32340               -32340 2023-05-23 01:05:00
# 5                -31734               -31734 2023-05-22 19:50:00
# 6                -32348               -32348 2023-05-22 22:30:00
# 7                -32456               -32456 2023-05-22 17:15:00
# 8                -32456               -32456 2023-05-22 18:30:00
# 9                -32128               -32128 2023-05-22 09:20:00
# 10               -32340               -32340 2023-05-22 21:15:00
# 11               -31734               -31734 2023-05-22 10:35:00
# 12               -32093               -32093 2023-05-22 21:50:00
# 13               -31461               -31461 2023-05-22 14:45:00
# 14               -30816               -30816 2023-05-22 17:00:00
# 15               -32093               -32093 2023-05-23 14:00:00
# 16               -32340               -32340 2023-05-23 10:00:00
# 17               -32348               -32348 2023-05-23 01:15:00
# 18               -32352               -32352 2023-05-22 23:55:00
#
#       arrival_datetime
# 0  2023-05-22 23:30:00
# 1  2023-05-23 09:35:00
# 2  2023-05-23 07:45:00
# 3  2023-05-22 18:55:00
# 4  2023-05-23 07:05:00
# 5  2023-05-22 21:55:00
# 6  2023-05-23 04:45:00
# 7  2023-05-22 21:20:00
# 8  2023-05-22 22:25:00
# 9  2023-05-22 11:45:00
# 10 2023-05-22 23:55:00
# 11 2023-05-22 17:50:00
# 12 2023-05-23 05:40:00
# 13 2023-05-22 19:35:00
# 14 2023-05-22 21:45:00
# 15 2023-05-23 18:50:00
# 16 2023-05-23 14:35:00
# 17 2023-05-23 04:45:00
# 18 2023-05-23 04:45:00

# %%
segment_test = segments['segment_id'].nunique()
segment_test
# Out:
# 19

# %% [markdown]
# ### Places

# %%
def clean_places_table(flight_tables):
    # subset
    places_dict = flight_tables['places']

    # format
    rows = []
    for key, value in places_dict.items():
        rows.append({
            'entity_id': value['entityId'],
            'parent_id': value['parentId'],
            'name': value['name'],
            'place_type': value['type'],
            'iata': value['iata'],
            'coordinates': value['coordinates']
        })


    # create dataframe
    return pd.DataFrame(rows)


# test
places = clean_places_table(flight_tables)
display(places.head())
# Out:
#    entity_id parent_id            name          place_type iata coordinates
# 0  128668132  27542065  Hong Kong Intl  PLACE_TYPE_AIRPORT  HKG        None
# 1  128668203  27536445     Addis Ababa  PLACE_TYPE_AIRPORT  ADD        None
# 2  128668889  27542089    Tokyo Narita  PLACE_TYPE_AIRPORT  NRT        None
# 3   27536445  29475224     Addis Ababa     PLACE_TYPE_CITY  ADD        None
# 4   27536671  29475320         Bangkok     PLACE_TYPE_CITY  BKK        None

# %% [markdown]
# ### Carriers

# %%
def clean_carriers_table(flight_tables):
    # subset
    carriers_dict = flight_tables['carriers']

    # format
    rows = []
    for key, value in carriers_dict.items():
        rows.append({
            'carrier_id': key,
            'name': value['name'],
            'alliance_id': value['allianceId'],
            'image_url': value['imageUrl'],
            'iata': value['iata']
        })



    # create dataframe
    return pd.DataFrame(rows)


# test
carriers = clean_carriers_table(flight_tables)
display(carriers.head())
# Out:
#   carrier_id              name alliance_id  \
# 0     -30816            Zipair
# 1     -31461    Thai AirAsia X
# 2     -31734  Turkish Airlines      -31999
# 3     -32093               LOT      -31999
# 4     -32128        Korean Air      -31998
#
#                                           image_url iata
# 0  https://logos.skyscnr.com/images/airlines/_Z.png   ZG
# 1  https://logos.skyscnr.com/images/airlines/XD.png   XJ
# 2  https://logos.skyscnr.com/images/airlines/TK.png   TK
# 3  https://logos.skyscnr.com/images/airlines/LO.png   LO
# 4  https://logos.skyscnr.com/images/airlines/KE.png   KE

# %% [markdown]
# ### Agents

# %%
def clean_agents_table(flight_tables):
    # subset
    agents_dict = flight_tables['agents']

    # format
    rows = []
    for key, value in agents_dict.items():
        rating_breakdown = value.get('ratingBreakdown') or {}
        rows.append({
            'agent_id': key,
            'name': value['name'],
            'agent_type': value['type'],
            'image_url': value['imageUrl'],
            'feedback_count': value['feedbackCount'],
            'rating': value['rating'],
            'customer_service': rating_breakdown.get('customerService', None),
            'reliable_prices': rating_breakdown.get('reliablePrices', None),
            'clear_extra_fees': rating_breakdown.get('clearExtraFees', None),
            'ease_of_booking': rating_breakdown.get('easeOfBooking', None),
            'other': rating_breakdown.get('other', None),
            'is_optimised_for_mobile': value['isOptimisedForMobile']
        })

    # create dataframe
    return pd.DataFrame(rows)


# test
agents = clean_agents_table(flight_tables)
display(agents.head())
# Out:
#   agent_id               name               agent_type  \
# 0     airf         Air France       AGENT_TYPE_AIRLINE
# 1     arus             Mytrip  AGENT_TYPE_TRAVEL_AGENT
# 2     ausa  Austrian Airlines       AGENT_TYPE_AIRLINE
# 3     bcom        Booking.com  AGENT_TYPE_TRAVEL_AGENT
# 4     bfus           Bravofly  AGENT_TYPE_TRAVEL_AGENT
#
#                                            image_url  feedback_count  rating  \
# 0  https://logos.skyscnr.com/images/websites/airf...            1903    2.87
# 1  https://logos.skyscnr.com/images/websites/arus...            8424    3.25
# 2  https://logos.skyscnr.com/images/websites/ausa...             364    3.75
# 3  https://logos.skyscnr.com/images/websites/bcom...            4381    3.62
# 4  https://logos.skyscnr.com/images/websites/bfus...            2773    2.62
#
#    customer_service  reliable_prices  clear_extra_fees  ease_of_booking  \
# 0          5.000000         1.668960          4.141784         2.992648
# 1          4.856892         3.538052          4.064076         3.325836
# 2          5.000000         3.303972          4.537448         3.612340
# 3          4.983912         3.188784          4.415532         3.849500
# 4          4.711384         2.962752          3.976468         1.484060
#
#       other  is_optimised_for_mobile
# 0  2.687180                     True
# 1  2.217688                     True
# 2  3.535248                     True
# 3  3.050716                     True
# 4  2.339328                     True

# %% [markdown]
# ### Alliances

# %%
def clean_alliances_table(flight_tables):
    # subset
    alliances_dict = flight_tables['alliances']

    # format
    rows = []
    for key, value in alliances_dict.items():
        rows.append({
            'alliance_id': key,
            'name': value['name']
        })

    # create dataframe
    return pd.DataFrame(rows)


# test
alliances = clean_alliances_table(flight_tables)
display(alliances.head())
# Out:
#   alliance_id           name
# 0      -31998        SkyTeam
# 1      -31999  Star Alliance
# 2      -32000       OneWorld

# %% [markdown]
# ## Combine

# %%
def create_full_journey_table(departure_airport, arrival_airport, itineraries_table, agents_table, segments_table, carriers_table, places_table):
    
    trips_df = itineraries_table
    
    # sort by id
    #trips_df = itineraries_table.sort_values(by="id", ascending=True)
    #trips_df = trips_df.sort_values(by="price_amount", ascending=True)
    
    # temp column to preserve order
    # Add a temporary column to store the original index
    trips_df['temp_index'] = trips_df.index
    
    
    # price to float
    trips_df['price_amount'] = trips_df['price_amount'].astype(float)

    # drop unecesary columns
    trips_df = trips_df.drop(['deep_link', 'option_id', 'booking_code', 'fare_basis_code', 'price_update_status'], axis=1)


    # bring in the agent name
    trips_df = pd.merge(trips_df, agents_table[['agent_id', 'name']], on='agent_id')
    trips_df = trips_df.rename(columns={'name': 'agent_name'})
    trips_df = trips_df.drop('agent_id', axis=1)

    # bring in segment info
    trips_df = pd.merge(trips_df, segments_table, on='segment_id')

    # get carrier names
    trips_df = pd.merge(trips_df, carriers_table[['carrier_id', 'name']], left_on='marketing_carrier_id', right_on='carrier_id')
    trips_df = trips_df.rename(columns={'name': 'marketing_carrier_name'})
    trips_df = pd.merge(trips_df, carriers_table[['carrier_id', 'name']], left_on='operating_carrier_id', right_on='carrier_id')
    trips_df = trips_df.rename(columns={'name': 'operating_carrier_name'})
    trips_df = trips_df.drop(['marketing_carrier_id', 'operating_carrier_id', 'carrier_id_x', 'carrier_id_y'], axis=1)

    # bring in places
    trips_df = pd.merge(trips_df, places_table[['entity_id', 'name', 'iata']], left_on='origin_place_id', right_on='entity_id')
    trips_df = trips_df.rename(columns={'name': 'origin_place_name', 'iata': 'origin_place_iata' })
    trips_df = pd.merge(trips_df, places_table[['entity_id', 'name', 'iata']], left_on='destination_place_id', right_on='entity_id')
    trips_df = trips_df.rename(columns={'name': 'destination_place_name', 'iata': 'destination_place_iata'})
    trips_df = trips_df.drop(['origin_place_id', 'destination_place_id', 'entity_id_x', 'entity_id_y'], axis=1)

    # results don't only show airports requested, remove unrequested airports
    #trips_df = trips_df[trips_df['origin_place_iata'] == departure_airport]
    #trips_df = trips_df[trips_df['destination_place_iata'] == arrival_airport]
    
    # sort and drop temp column
    # Sort the merged DataFrame based on the temporary column
    trips_df = trips_df.sort_values('temp_index')

    # Drop the temporary column
    trips_df = trips_df.drop('temp_index', axis=1)
    
    #trips_df = trips_df.sort_values(by=['price_amount', 'id'], ascending=[True, True])

    return trips_df


# test
trips_df = create_full_journey_table('NRT', 'TPE', itineraries, agents, segments, carriers, places)
display(trips_df.head(100))
# Out:
#                                                    id  price_amount  \
# 0   14788-2305220920--32128,-32301-2-16995-2305222330     1003560.0
# 7   14788-2305220920--32128,-32301-2-16995-2305222330     1003560.0
# 13  14788-2305220920--32128,-32301-2-16995-2305222330     1003560.0
# 2          14788-2305221035--31734-1-16995-2305222155     1039990.0
# 16         14788-2305221035--31734-1-16995-2305222155     1039990.0
# 3   14788-2305221445--31461,-32352-1-16995-2305230445      919990.0
# 17  14788-2305221445--31461,-32352-1-16995-2305230445      919990.0
# 4   14788-2305221700--30816,-32348-2-16995-2305230935      855600.0
# 8   14788-2305221700--30816,-32348-2-16995-2305230935      855600.0
# 14  14788-2305221700--30816,-32348-2-16995-2305230935      855600.0
# 5   14788-2305221700--30816,-32352-1-16995-2305230445      901900.0
# 18  14788-2305221700--30816,-32352-1-16995-2305230445      901900.0
# 9          14788-2305221715--32456-1-16995-2305230745     1030700.0
# 20         14788-2305221715--32456-1-16995-2305230745     1030700.0
# 10         14788-2305221830--32456-1-16995-2305230745     1135700.0
# 21         14788-2305221830--32456-1-16995-2305230745     1135700.0
# 1          14788-2305222115--32340-2-16995-2305231435      611900.0
# 12         14788-2305222115--32340-2-16995-2305231435      611900.0
# 19         14788-2305222115--32340-2-16995-2305231435      611900.0
# 11         14788-2305222150--32093-1-16995-2305231850      758700.0
# 22         14788-2305222150--32093-1-16995-2305231850      758700.0
# 6          14788-2305222230--32348-1-16995-2305230935     1080000.0
# 15         14788-2305222230--32348-1-16995-2305230935     1080000.0
#
#           price_unit                                segment_id  \
# 0   PRICE_UNIT_MILLI  14788-12409-2305220920-2305221145--32128
# 7   PRICE_UNIT_MILLI  12409-11182-2305221330-2305221855--32128
# 13  PRICE_UNIT_MILLI  11182-16995-2305222055-2305222330--32301
# 2   PRICE_UNIT_MILLI  14788-12585-2305221035-2305221750--31734
# 16  PRICE_UNIT_MILLI  12585-16995-2305221950-2305222155--31734
# 3   PRICE_UNIT_MILLI   14788-9970-2305221445-2305221935--31461
# 17  PRICE_UNIT_MILLI   9970-16995-2305222355-2305230445--32352
# 4   PRICE_UNIT_MILLI   14788-9970-2305221700-2305222145--30816
# 8   PRICE_UNIT_MILLI   9970-11182-2305230115-2305230445--32348
# 14  PRICE_UNIT_MILLI  11182-16995-2305230705-2305230935--32348
# 5   PRICE_UNIT_MILLI   14788-9970-2305221700-2305222145--30816
# 18  PRICE_UNIT_MILLI   9970-16995-2305222355-2305230445--32352
# 9   PRICE_UNIT_MILLI  14788-12191-2305221715-2305222120--32456
# 20  PRICE_UNIT_MILLI  12191-16995-2305230220-2305230745--32456
# 10  PRICE_UNIT_MILLI  14788-12191-2305221830-2305222225--32456
# 21  PRICE_UNIT_MILLI  12191-16995-2305230220-2305230745--32456
# 1   PRICE_UNIT_MILLI  14788-12409-2305222115-2305222355--32340
# 12  PRICE_UNIT_MILLI   12409-9252-2305230105-2305230705--32340
# 19  PRICE_UNIT_MILLI   9252-16995-2305231000-2305231435--32340
# 11  PRICE_UNIT_MILLI  14788-17648-2305222150-2305230540--32093
# 22  PRICE_UNIT_MILLI  17648-16995-2305231400-2305231850--32093
# 6   PRICE_UNIT_MILLI  14788-11182-2305222230-2305230445--32348
# 15  PRICE_UNIT_MILLI  11182-16995-2305230705-2305230935--32348
#
#                             transfer_type     agent_name  duration_minutes  \
# 0   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER        eDreams               145
# 7   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER        eDreams               625
# 13  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER        eDreams               215
# 2                   TRANSFER_TYPE_MANAGED  FlightNetwork               795
# 16                  TRANSFER_TYPE_MANAGED  FlightNetwork               125
# 3   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               410
# 17  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               530
# 4   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               405
# 8   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               390
# 14  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               210
# 5   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               405
# 18  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               530
# 9                   TRANSFER_TYPE_MANAGED     SmartFares               305
# 20                  TRANSFER_TYPE_MANAGED     SmartFares               625
# 10                  TRANSFER_TYPE_MANAGED     SmartFares               295
# 21                  TRANSFER_TYPE_MANAGED     SmartFares               625
# 1                   TRANSFER_TYPE_MANAGED       Trip.com               160
# 12                  TRANSFER_TYPE_MANAGED       Trip.com               720
# 19                  TRANSFER_TYPE_MANAGED       Trip.com               275
# 11                  TRANSFER_TYPE_MANAGED     SmartFares               890
# 22                  TRANSFER_TYPE_MANAGED     SmartFares               230
# 6                   TRANSFER_TYPE_MANAGED       Trip.com               675
# 15                  TRANSFER_TYPE_MANAGED       Trip.com               210
#
#    marketing_flight_number  departure_datetime    arrival_datetime  \
# 0                      706 2023-05-22 09:20:00 2023-05-22 11:45:00
# 7                      951 2023-05-22 13:30:00 2023-05-22 18:55:00
# 13                    1807 2023-05-22 20:55:00 2023-05-22 23:30:00
# 2                       51 2023-05-22 10:35:00 2023-05-22 17:50:00
# 16                     864 2023-05-22 19:50:00 2023-05-22 21:55:00
# 3                      603 2023-05-22 14:45:00 2023-05-22 19:35:00
# 17                      82 2023-05-22 23:55:00 2023-05-23 04:45:00
# 4                       51 2023-05-22 17:00:00 2023-05-22 21:45:00
# 8                      385 2023-05-23 01:15:00 2023-05-23 04:45:00
# 14                    2369 2023-05-23 07:05:00 2023-05-23 09:35:00
# 5                       51 2023-05-22 17:00:00 2023-05-22 21:45:00
# 18                      82 2023-05-22 23:55:00 2023-05-23 04:45:00
# 9                      521 2023-05-22 17:15:00 2023-05-22 21:20:00
# 20                     675 2023-05-23 02:20:00 2023-05-23 07:45:00
# 10                     505 2023-05-22 18:30:00 2023-05-22 22:25:00
# 21                     675 2023-05-23 02:20:00 2023-05-23 07:45:00
# 1                      673 2023-05-22 21:15:00 2023-05-22 23:55:00
# 12                     673 2023-05-23 01:05:00 2023-05-23 07:05:00
# 19                     418 2023-05-23 10:00:00 2023-05-23 14:35:00
# 11                      80 2023-05-22 21:50:00 2023-05-23 05:40:00
# 22                     155 2023-05-23 14:00:00 2023-05-23 18:50:00
# 6                      319 2023-05-22 22:30:00 2023-05-23 04:45:00
# 15                    2369 2023-05-23 07:05:00 2023-05-23 09:35:00
#
#    marketing_carrier_name operating_carrier_name  \
# 0              Korean Air             Korean Air
# 7              Korean Air             Korean Air
# 13               flydubai               flydubai
# 2        Turkish Airlines       Turkish Airlines
# 16       Turkish Airlines       Turkish Airlines
# 3          Thai AirAsia X         Thai AirAsia X
# 17  EL AL Israel Airlines  EL AL Israel Airlines
# 4                  Zipair                 Zipair
# 8                Emirates               Emirates
# 14               Emirates               flydubai
# 5                  Zipair                 Zipair
# 18  EL AL Israel Airlines  EL AL Israel Airlines
# 9          Cathay Pacific         Cathay Pacific
# 20         Cathay Pacific         Cathay Pacific
# 10         Cathay Pacific         Cathay Pacific
# 21         Cathay Pacific         Cathay Pacific
# 1      Ethiopian Airlines     Ethiopian Airlines
# 12     Ethiopian Airlines     Ethiopian Airlines
# 19     Ethiopian Airlines     Ethiopian Airlines
# 11                    LOT                    LOT
# 22                    LOT                    LOT
# 6                Emirates               Emirates
# 15               Emirates               flydubai
#
#                 origin_place_name origin_place_iata  \
# 0                    Tokyo Narita               NRT
# 7   Incheon International Airport               ICN
# 13                          Dubai               DXB
# 2                    Tokyo Narita               NRT
# 16                       Istanbul               IST
# 3                    Tokyo Narita               NRT
# 17           Bangkok Suvarnabhumi               BKK
# 4                    Tokyo Narita               NRT
# 8            Bangkok Suvarnabhumi               BKK
# 14                          Dubai               DXB
# 5                    Tokyo Narita               NRT
# 18           Bangkok Suvarnabhumi               BKK
# 9                    Tokyo Narita               NRT
# 20                 Hong Kong Intl               HKG
# 10                   Tokyo Narita               NRT
# 21                 Hong Kong Intl               HKG
# 1                    Tokyo Narita               NRT
# 12  Incheon International Airport               ICN
# 19                    Addis Ababa               ADD
# 11                   Tokyo Narita               NRT
# 22                  Warsaw Chopin               WAW
# 6                    Tokyo Narita               NRT
# 15                          Dubai               DXB
#
#            destination_place_name destination_place_iata
# 0   Incheon International Airport                    ICN
# 7                           Dubai                    DXB
# 13                Ben Gurion Intl                    TLV
# 2                        Istanbul                    IST
# 16                Ben Gurion Intl                    TLV
# 3            Bangkok Suvarnabhumi                    BKK
# 17                Ben Gurion Intl                    TLV
# 4            Bangkok Suvarnabhumi                    BKK
# 8                           Dubai                    DXB
# 14                Ben Gurion Intl                    TLV
# 5            Bangkok Suvarnabhumi                    BKK
# 18                Ben Gurion Intl                    TLV
# 9                  Hong Kong Intl                    HKG
# 20                Ben Gurion Intl                    TLV
# 10                 Hong Kong Intl                    HKG
# 21                Ben Gurion Intl                    TLV
# 1   Incheon International Airport                    ICN
# 12                    Addis Ababa                    ADD
# 19                Ben Gurion Intl                    TLV
# 11                  Warsaw Chopin                    WAW
# 22                Ben Gurion Intl                    TLV
# 6                           Dubai                    DXB
# 15                Ben Gurion Intl                    TLV

# %% [markdown]
# ## Single function

# %%
# set departure and arrival airports
departure_airport = 'NRT'
arrival_airport = 'TLV'

def get_flight_data(departure_airport, arrival_airport, year, month, day):

    flight_tables = get_flight_tables(departure_airport, arrival_airport, year, month, day)

    itineraries_table = clean_itineraries_table(flight_tables)
    agents_table = clean_agents_table(flight_tables)
    segments_table = clean_segments_table(flight_tables)
    carriers_table = clean_carriers_table(flight_tables)
    places_table =clean_places_table(flight_tables)

    return create_full_journey_table(departure_airport, arrival_airport, itineraries_table, agents_table, segments_table, carriers_table, places_table)

get_flight_data(departure_airport, arrival_airport, 2023, 5, 22)
# Out:
#                                                    id  price_amount  \
# 0   14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 11  14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 23  14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 15  14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 4   14788-2305220930--31705,-32339,-31669-3-16995-...      560990.0
# 12  14788-2305220930--31705,-32339,-31669-3-16995-...      560990.0
# 24  14788-2305220930--31705,-32339,-31669-3-16995-...      560990.0
# 16  14788-2305220930--31705,-32339,-31669-3-16995-...      560990.0
# 5          14788-2305221035--31734-1-16995-2305222155     1039990.0
# 17         14788-2305221035--31734-1-16995-2305222155     1039990.0
# 1   14788-2305221445--31461,-32352-1-16995-2305230445      919990.0
# 13  14788-2305221445--31461,-32352-1-16995-2305230445      919990.0
# 2   14788-2305221700--30816,-32348-2-16995-2305230935      856900.0
# 7   14788-2305221700--30816,-32348-2-16995-2305230935      856900.0
# 18  14788-2305221700--30816,-32348-2-16995-2305230935      856900.0
# 3   14788-2305221700--30816,-32352-1-16995-2305230445      898900.0
# 14  14788-2305221700--30816,-32352-1-16995-2305230445      898900.0
# 9          14788-2305221715--32456-1-16995-2305230745     1030700.0
# 21         14788-2305221715--32456-1-16995-2305230745     1030700.0
# 8          14788-2305222115--32340-2-16995-2305231435      611900.0
# 25         14788-2305222115--32340-2-16995-2305231435      611900.0
# 20         14788-2305222115--32340-2-16995-2305231435      611900.0
# 10         14788-2305222150--32093-1-16995-2305231850      758700.0
# 22         14788-2305222150--32093-1-16995-2305231850      758700.0
# 6          14788-2305222230--32348-1-16995-2305230935     1080000.0
# 19         14788-2305222230--32348-1-16995-2305230935     1080000.0
#
#           price_unit                                segment_id  \
# 0   PRICE_UNIT_MILLI   14788-9970-2305220915-2305221400--31461
# 11  PRICE_UNIT_MILLI   9970-10075-2305221550-2305221835--32213
# 23  PRICE_UNIT_MILLI   10075-9618-2305222215-2305222345--32213
# 15  PRICE_UNIT_MILLI   9618-16995-2305230810-2305231050--31669
# 4   PRICE_UNIT_MILLI  14788-12071-2305220930-2305221305--31705
# 12  PRICE_UNIT_MILLI  12071-10075-2305221820-2305222150--31705
# 24  PRICE_UNIT_MILLI   10075-9618-2305230445-2305230610--32339
# 16  PRICE_UNIT_MILLI   9618-16995-2305230810-2305231050--31669
# 5   PRICE_UNIT_MILLI  14788-12585-2305221035-2305221750--31734
# 17  PRICE_UNIT_MILLI  12585-16995-2305221950-2305222155--31734
# 1   PRICE_UNIT_MILLI   14788-9970-2305221445-2305221935--31461
# 13  PRICE_UNIT_MILLI   9970-16995-2305222355-2305230445--32352
# 2   PRICE_UNIT_MILLI   14788-9970-2305221700-2305222145--30816
# 7   PRICE_UNIT_MILLI   9970-11182-2305230115-2305230445--32348
# 18  PRICE_UNIT_MILLI  11182-16995-2305230705-2305230935--32348
# 3   PRICE_UNIT_MILLI   14788-9970-2305221700-2305222145--30816
# 14  PRICE_UNIT_MILLI   9970-16995-2305222355-2305230445--32352
# 9   PRICE_UNIT_MILLI  14788-12191-2305221715-2305222120--32456
# 21  PRICE_UNIT_MILLI  12191-16995-2305230220-2305230745--32456
# 8   PRICE_UNIT_MILLI  14788-12409-2305222115-2305222355--32340
# 25  PRICE_UNIT_MILLI   12409-9252-2305230105-2305230705--32340
# 20  PRICE_UNIT_MILLI   9252-16995-2305231000-2305231435--32340
# 10  PRICE_UNIT_MILLI  14788-17648-2305222150-2305230540--32093
# 22  PRICE_UNIT_MILLI  17648-16995-2305231400-2305231850--32093
# 6   PRICE_UNIT_MILLI  14788-11182-2305222230-2305230445--32348
# 19  PRICE_UNIT_MILLI  11182-16995-2305230705-2305230935--32348
#
#                             transfer_type     agent_name  duration_minutes  \
# 0   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               405
# 11  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               255
# 23  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               180
# 15  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               220
# 4   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               335
# 12  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               300
# 24  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               175
# 16  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               220
# 5                   TRANSFER_TYPE_MANAGED  FlightNetwork               795
# 17                  TRANSFER_TYPE_MANAGED  FlightNetwork               125
# 1   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       GotoGate               410
# 13  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       GotoGate               530
# 2   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               405
# 7   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               390
# 18  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               210
# 3   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               405
# 14  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               530
# 9                   TRANSFER_TYPE_MANAGED     SmartFares               305
# 21                  TRANSFER_TYPE_MANAGED     SmartFares               625
# 8                   TRANSFER_TYPE_MANAGED       Trip.com               160
# 25                  TRANSFER_TYPE_MANAGED       Trip.com               720
# 20                  TRANSFER_TYPE_MANAGED       Trip.com               275
# 10                  TRANSFER_TYPE_MANAGED     SmartFares               890
# 22                  TRANSFER_TYPE_MANAGED     SmartFares               230
# 6                   TRANSFER_TYPE_MANAGED       Trip.com               675
# 19                  TRANSFER_TYPE_MANAGED       Trip.com               210
#
#    marketing_flight_number  departure_datetime    arrival_datetime  \
# 0                      601 2023-05-22 09:15:00 2023-05-22 14:00:00
# 11                    1052 2023-05-22 15:50:00 2023-05-22 18:35:00
# 23                    1401 2023-05-22 22:15:00 2023-05-22 23:45:00
# 15                    7085 2023-05-23 08:10:00 2023-05-23 10:50:00
# 4                      933 2023-05-22 09:30:00 2023-05-22 13:05:00
# 12                     907 2023-05-22 18:20:00 2023-05-22 21:50:00
# 24                     205 2023-05-23 04:45:00 2023-05-23 06:10:00
# 16                    7085 2023-05-23 08:10:00 2023-05-23 10:50:00
# 5                       51 2023-05-22 10:35:00 2023-05-22 17:50:00
# 17                     864 2023-05-22 19:50:00 2023-05-22 21:55:00
# 1                      603 2023-05-22 14:45:00 2023-05-22 19:35:00
# 13                      82 2023-05-22 23:55:00 2023-05-23 04:45:00
# 2                       51 2023-05-22 17:00:00 2023-05-22 21:45:00
# 7                      385 2023-05-23 01:15:00 2023-05-23 04:45:00
# 18                    2369 2023-05-23 07:05:00 2023-05-23 09:35:00
# 3                       51 2023-05-22 17:00:00 2023-05-22 21:45:00
# 14                      82 2023-05-22 23:55:00 2023-05-23 04:45:00
# 9                      521 2023-05-22 17:15:00 2023-05-22 21:20:00
# 21                     675 2023-05-23 02:20:00 2023-05-23 07:45:00
# 8                      673 2023-05-22 21:15:00 2023-05-22 23:55:00
# 25                     673 2023-05-23 01:05:00 2023-05-23 07:05:00
# 20                     418 2023-05-23 10:00:00 2023-05-23 14:35:00
# 10                      80 2023-05-22 21:50:00 2023-05-23 05:40:00
# 22                     155 2023-05-23 14:00:00 2023-05-23 18:50:00
# 6                      319 2023-05-22 22:30:00 2023-05-23 04:45:00
# 19                    2369 2023-05-23 07:05:00 2023-05-23 09:35:00
#
#    marketing_carrier_name operating_carrier_name  \
# 0          Thai AirAsia X         Thai AirAsia X
# 11                 IndiGo                 IndiGo
# 23                 IndiGo                 IndiGo
# 15               Wizz Air     Wizz Air Abu Dhabi
# 4             VietJet Air            VietJet Air
# 12            VietJet Air            VietJet Air
# 24         Etihad Airways         Etihad Airways
# 16               Wizz Air     Wizz Air Abu Dhabi
# 5        Turkish Airlines       Turkish Airlines
# 17       Turkish Airlines       Turkish Airlines
# 1          Thai AirAsia X         Thai AirAsia X
# 13  EL AL Israel Airlines  EL AL Israel Airlines
# 2                  Zipair                 Zipair
# 7                Emirates               Emirates
# 18               Emirates               flydubai
# 3                  Zipair                 Zipair
# 14  EL AL Israel Airlines  EL AL Israel Airlines
# 9          Cathay Pacific         Cathay Pacific
# 21         Cathay Pacific         Cathay Pacific
# 8      Ethiopian Airlines     Ethiopian Airlines
# 25     Ethiopian Airlines     Ethiopian Airlines
# 20     Ethiopian Airlines     Ethiopian Airlines
# 10                    LOT                    LOT
# 22                    LOT                    LOT
# 6                Emirates               Emirates
# 19               Emirates               flydubai
#
#                 origin_place_name origin_place_iata  \
# 0                    Tokyo Narita               NRT
# 11           Bangkok Suvarnabhumi               BKK
# 23                         Mumbai               BOM
# 15        Abu Dhabi International               AUH
# 4                    Tokyo Narita               NRT
# 12                          Hanoi               HAN
# 24                         Mumbai               BOM
# 16        Abu Dhabi International               AUH
# 5                    Tokyo Narita               NRT
# 17                       Istanbul               IST
# 1                    Tokyo Narita               NRT
# 13           Bangkok Suvarnabhumi               BKK
# 2                    Tokyo Narita               NRT
# 7            Bangkok Suvarnabhumi               BKK
# 18                          Dubai               DXB
# 3                    Tokyo Narita               NRT
# 14           Bangkok Suvarnabhumi               BKK
# 9                    Tokyo Narita               NRT
# 21                 Hong Kong Intl               HKG
# 8                    Tokyo Narita               NRT
# 25  Incheon International Airport               ICN
# 20                    Addis Ababa               ADD
# 10                   Tokyo Narita               NRT
# 22                  Warsaw Chopin               WAW
# 6                    Tokyo Narita               NRT
# 19                          Dubai               DXB
#
#            destination_place_name destination_place_iata
# 0            Bangkok Suvarnabhumi                    BKK
# 11                         Mumbai                    BOM
# 23        Abu Dhabi International                    AUH
# 15                Ben Gurion Intl                    TLV
# 4                           Hanoi                    HAN
# 12                         Mumbai                    BOM
# 24        Abu Dhabi International                    AUH
# 16                Ben Gurion Intl                    TLV
# 5                        Istanbul                    IST
# 17                Ben Gurion Intl                    TLV
# 1            Bangkok Suvarnabhumi                    BKK
# 13                Ben Gurion Intl                    TLV
# 2            Bangkok Suvarnabhumi                    BKK
# 7                           Dubai                    DXB
# 18                Ben Gurion Intl                    TLV
# 3            Bangkok Suvarnabhumi                    BKK
# 14                Ben Gurion Intl                    TLV
# 9                  Hong Kong Intl                    HKG
# 21                Ben Gurion Intl                    TLV
# 8   Incheon International Airport                    ICN
# 25                    Addis Ababa                    ADD
# 20                Ben Gurion Intl                    TLV
# 10                  Warsaw Chopin                    WAW
# 22                Ben Gurion Intl                    TLV
# 6                           Dubai                    DXB
# 19                Ben Gurion Intl                    TLV

# %% [markdown]
# ## Loop

# %%
iata_codes_list = capital_cities['airport_iata'].tolist()
#iata_codes_list[:5]
iata_codes_list
# Out:
# ['KBL',
#  'EVN',
#  'GYD',
#  'BAH',
#  'DAC',
#  'BWN',
#  'PNH',
#  'PEK',
#  'LCA',
#  'DIL',
#  'TBS',
#  'DEL',
#  'CGK',
#  'IKA',
#  'BGW',
#  'TLV',
#  'NRT',
#  'AMM',
#  'NQZ',
#  'KWI',
#  'FRU',
#  'VTE',
#  'BEY',
#  'KUL',
#  'MLE',
#  'UBN',
#  'NYT',
#  'KTM',
#  'MCT',
#  'ISB',
#  'MNL',
#  'DOH',
#  'RUH',
#  'SIN',
#  'ICN',
#  'CMB',
#  'DAM',
#  'TPE',
#  'DYU',
#  'BKK',
#  'ESB',
#  'ASB',
#  'AUH',
#  'TAS',
#  'HAN']

# %%
# get airport pairs without departing and arriving at same place
airport_pairs = [(iata_codes_list[i], iata_codes_list[j]) for i in range(len(iata_codes_list)) for j in range(len(iata_codes_list)) if i != j]
display(len(iata_codes_list))
display(len(airport_pairs))
# Out:
# 45
# 1980

# %%
# use shorter if needed
if True == False:
    airport_pairs_for_run = airport_pairs[-5:]
    len(airport_pairs_for_run)
    display(airport_pairs_for_run)
else:
    airport_pairs_for_run = airport_pairs
    len(airport_pairs_for_run)
    display(airport_pairs_for_run[:5])
# Out:
# [('KBL', 'EVN'),
#  ('KBL', 'GYD'),
#  ('KBL', 'BAH'),
#  ('KBL', 'DAC'),
#  ('KBL', 'BWN')]

# %%
# timestamp so all files have the same time
timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
#timestamp = '2023-04-26_03-36-24'

timestamped_directory = f'../Data/FlightAPIData/{timestamp}/'
if not os.path.exists(timestamped_directory):
    os.makedirs(timestamped_directory)

time_sleep_sec = 2
year = 2023
month = 5
day = 22

for departure in iata_codes_list:



    if departure in ['KBL', 'EVN', 'GYD', 'BAH', 'DAC', 'DAC','BWN','PNH','PEK', 'LCA', 'DIL', 'TBS', 'DEL', 'CGK', 'IKA', 'BGW','TLV','NRT','AMM','NQZ','KWI','FRU','VTE','BEY','KUL','MLE']:
        continue
    
    # init empty list
    dataframes = []
    
    for arrival in iata_codes_list:
        
        # skip if departure and arrival airport are the same
        if departure == arrival:
            continue
        
        
        try:
            print(f'trying - departure: {departure}, arrival: {arrival}')
            df = get_flight_data(departure, arrival, year, month, day)
            df['departure_query'] = departure
            df['arrival_query'] = arrival
            dataframes.append(df)
            print('success')
            
            # sleep to avoid hitting the api limit
            time.sleep(time_sleep_sec)
        except Exception as e:
            print(f"error while processing {departure}-{arrival}: {e}")
            # sleep to avoid hitting the api limit
            time.sleep(time_sleep_sec)
            continue
    
    # concat the dataframes
    combined_dataframe = pd.concat(dataframes, ignore_index=True)
    #combine_to_datetime(combined_dataframe, 'arrival')
    #combine_to_datetime(combined_dataframe, 'departure')

    # save
    combined_dataframe.to_csv(f'../Data/FlightAPIData/{timestamp}/{timestamp}_{departure}_flight_api_data.csv', index=False)

# show
display(combined_dataframe.head())
# Out:
# trying - departure: BGW, arrival: KBL
# error while processing BGW-KBL: No itineraries!
# trying - departure: BGW, arrival: EVN
# success
# trying - departure: BGW, arrival: GYD
# success
# trying - departure: BGW, arrival: BAH
# success
# trying - departure: BGW, arrival: DAC
# success
# trying - departure: BGW, arrival: BWN
# success
# trying - departure: BGW, arrival: PNH
# success
# trying - departure: BGW, arrival: PEK
# success
# trying - departure: BGW, arrival: LCA
# success
# trying - departure: BGW, arrival: DIL
# success
# trying - departure: BGW, arrival: TBS
# success
# trying - departure: BGW, arrival: DEL
# success
# trying - departure: BGW, arrival: CGK
# success
# trying - departure: BGW, arrival: IKA
# success
# trying - departure: BGW, arrival: TLV
# success
# trying - departure: BGW, arrival: NRT
# success
# trying - departure: BGW, arrival: AMM
# success
# trying - departure: BGW, arrival: NQZ
# success
# trying - departure: BGW, arrival: KWI
# success
# trying - departure: BGW, arrival: FRU
# success
# trying - departure: BGW, arrival: VTE
# success
# trying - departure: BGW, arrival: BEY
# success
# trying - departure: BGW, arrival: KUL
# success
# trying - departure: BGW, arrival: MLE
# success
# trying - departure: BGW, arrival: UBN
# success
# trying - departure: BGW, arrival: NYT
# error while processing BGW-NYT: No itineraries!
# trying - departure: BGW, arrival: KTM
# success
# trying - departure: BGW, arrival: MCT
# success
# trying - departure: BGW, arrival: ISB
# success
# trying - departure: BGW, arrival: MNL
# success
# trying - departure: BGW, arrival: DOH
# success
# trying - departure: BGW, arrival: RUH
# success
# trying - departure: BGW, arrival: SIN
# success
# trying - departure: BGW, arrival: ICN
# success
# trying - departure: BGW, arrival: CMB
# success
# trying - departure: BGW, arrival: DAM
# error while processing BGW-DAM: No itineraries!
# trying - departure: BGW, arrival: TPE
# success
# trying - departure: BGW, arrival: DYU
# success
# trying - departure: BGW, arrival: BKK
# success
# trying - departure: BGW, arrival: ESB
# error while processing BGW-ESB: No itineraries!
# trying - departure: BGW, arrival: ASB
# success
# trying - departure: BGW, arrival: AUH
# success
# trying - departure: BGW, arrival: TAS
# success
# trying - departure: BGW, arrival: HAN
# success
# trying - departure: TLV, arrival: KBL
# success
# trying - departure: TLV, arrival: EVN
# success
# trying - departure: TLV, arrival: GYD
# success
# trying - departure: TLV, arrival: BAH
# success
# trying - departure: TLV, arrival: DAC
# success
# trying - departure: TLV, arrival: BWN
# success
# trying - departure: TLV, arrival: PNH
# success
# trying - departure: TLV, arrival: PEK
# success
# trying - departure: TLV, arrival: LCA
# success
# trying - departure: TLV, arrival: DIL
# success
# trying - departure: TLV, arrival: TBS
# success
# trying - departure: TLV, arrival: DEL
# success
# trying - departure: TLV, arrival: CGK
# success
# trying - departure: TLV, arrival: IKA
# success
# trying - departure: TLV, arrival: BGW
# success
# trying - departure: TLV, arrival: NRT
# success
# trying - departure: TLV, arrival: AMM
# success
# trying - departure: TLV, arrival: NQZ
# success
# trying - departure: TLV, arrival: KWI
# success
# trying - departure: TLV, arrival: FRU
# success
# trying - departure: TLV, arrival: VTE
# success
# trying - departure: TLV, arrival: BEY
# success
# trying - departure: TLV, arrival: KUL
# success
# trying - departure: TLV, arrival: MLE
# success
# trying - departure: TLV, arrival: UBN
# success
# trying - departure: TLV, arrival: NYT
# error while processing TLV-NYT: No itineraries!
# trying - departure: TLV, arrival: KTM
# success
# trying - departure: TLV, arrival: MCT
# success
# trying - departure: TLV, arrival: ISB
# success
# trying - departure: TLV, arrival: MNL
# success
# trying - departure: TLV, arrival: DOH
# success
# trying - departure: TLV, arrival: RUH
# success
# trying - departure: TLV, arrival: SIN
# success
# trying - departure: TLV, arrival: ICN
# success
# trying - departure: TLV, arrival: CMB
# success
# trying - departure: TLV, arrival: DAM
# error while processing TLV-DAM: No itineraries!
# trying - departure: TLV, arrival: TPE
# success
# trying - departure: TLV, arrival: DYU
# success
# trying - departure: TLV, arrival: BKK
# success
# trying - departure: TLV, arrival: ESB
# success
# trying - departure: TLV, arrival: ASB
# success
# trying - departure: TLV, arrival: AUH
# success
# trying - departure: TLV, arrival: TAS
# success
# trying - departure: TLV, arrival: HAN
# success
# trying - departure: NRT, arrival: KBL
# error while processing NRT-KBL: No itineraries!
# trying - departure: NRT, arrival: EVN
# success
# trying - departure: NRT, arrival: GYD
# success
# trying - departure: NRT, arrival: BAH
# success
# trying - departure: NRT, arrival: DAC
# success
# trying - departure: NRT, arrival: BWN
# success
# trying - departure: NRT, arrival: PNH
# success
# trying - departure: NRT, arrival: PEK
# success
# trying - departure: NRT, arrival: LCA
# success
# trying - departure: NRT, arrival: DIL
# success
# trying - departure: NRT, arrival: TBS
# success
# trying - departure: NRT, arrival: DEL
# success
# trying - departure: NRT, arrival: CGK
# success
# trying - departure: NRT, arrival: IKA
# success
# trying - departure: NRT, arrival: BGW
# success
# trying - departure: NRT, arrival: TLV
# success
# trying - departure: NRT, arrival: AMM
# success
# trying - departure: NRT, arrival: NQZ
# success
# trying - departure: NRT, arrival: KWI
# success
# trying - departure: NRT, arrival: FRU
# success
# trying - departure: NRT, arrival: VTE
# success
# trying - departure: NRT, arrival: BEY
# success
# trying - departure: NRT, arrival: KUL
# success
# trying - departure: NRT, arrival: MLE
# success
# trying - departure: NRT, arrival: UBN
# success
# trying - departure: NRT, arrival: NYT
# error while processing NRT-NYT: No itineraries!
# trying - departure: NRT, arrival: KTM
# success
# trying - departure: NRT, arrival: MCT
# success
# trying - departure: NRT, arrival: ISB
# success
# trying - departure: NRT, arrival: MNL
# success
# trying - departure: NRT, arrival: DOH
# success
# trying - departure: NRT, arrival: RUH
# success
# trying - departure: NRT, arrival: SIN
# success
# trying - departure: NRT, arrival: ICN
# success
# trying - departure: NRT, arrival: CMB
# success
# trying - departure: NRT, arrival: DAM
# error while processing NRT-DAM: No itineraries!
# trying - departure: NRT, arrival: TPE
# success
# trying - departure: NRT, arrival: DYU
# success
# trying - departure: NRT, arrival: BKK
# success
# trying - departure: NRT, arrival: ESB
# success
# trying - departure: NRT, arrival: ASB
# success
# trying - departure: NRT, arrival: AUH
# success
# trying - departure: NRT, arrival: TAS
# success
# trying - departure: NRT, arrival: HAN
# success
# trying - departure: AMM, arrival: KBL
# error while processing AMM-KBL: No itineraries!
# trying - departure: AMM, arrival: EVN
# success
# trying - departure: AMM, arrival: GYD
# success
# trying - departure: AMM, arrival: BAH
# success
# trying - departure: AMM, arrival: DAC
# success
# trying - departure: AMM, arrival: BWN
# success
# trying - departure: AMM, arrival: PNH
# success
# trying - departure: AMM, arrival: PEK
# success
# trying - departure: AMM, arrival: LCA
# success
# trying - departure: AMM, arrival: DIL
# success
# trying - departure: AMM, arrival: TBS
# success
# trying - departure: AMM, arrival: DEL
# success
# trying - departure: AMM, arrival: CGK
# success
# trying - departure: AMM, arrival: IKA
# success
# trying - departure: AMM, arrival: BGW
# success
# trying - departure: AMM, arrival: TLV
# success
# trying - departure: AMM, arrival: NRT
# success
# trying - departure: AMM, arrival: NQZ
# success
# trying - departure: AMM, arrival: KWI
# success
# trying - departure: AMM, arrival: FRU
# success
# trying - departure: AMM, arrival: VTE
# success
# trying - departure: AMM, arrival: BEY
# success
# trying - departure: AMM, arrival: KUL
# success
# trying - departure: AMM, arrival: MLE
# success
# trying - departure: AMM, arrival: UBN
# success
# trying - departure: AMM, arrival: NYT
# error while processing AMM-NYT: No itineraries!
# trying - departure: AMM, arrival: KTM
# success
# trying - departure: AMM, arrival: MCT
# success
# trying - departure: AMM, arrival: ISB
# success
# trying - departure: AMM, arrival: MNL
# success
# trying - departure: AMM, arrival: DOH
# success
# trying - departure: AMM, arrival: RUH
# success
# trying - departure: AMM, arrival: SIN
# success
# trying - departure: AMM, arrival: ICN
# success
# trying - departure: AMM, arrival: CMB
# success
# trying - departure: AMM, arrival: DAM
# error while processing AMM-DAM: No itineraries!
# trying - departure: AMM, arrival: TPE
# success
# trying - departure: AMM, arrival: DYU
# success
# trying - departure: AMM, arrival: BKK
# success
# trying - departure: AMM, arrival: ESB
# success
# trying - departure: AMM, arrival: ASB
# success
# trying - departure: AMM, arrival: AUH
# success
# trying - departure: AMM, arrival: TAS
# success
# trying - departure: AMM, arrival: HAN
# success
# trying - departure: NQZ, arrival: KBL
# error while processing NQZ-KBL: No itineraries!
# trying - departure: NQZ, arrival: EVN
# success
# trying - departure: NQZ, arrival: GYD
# success
# trying - departure: NQZ, arrival: BAH
# success
# trying - departure: NQZ, arrival: DAC
# success
# trying - departure: NQZ, arrival: BWN
# error while processing NQZ-BWN: No itineraries!
# trying - departure: NQZ, arrival: PNH
# error while processing NQZ-PNH: No itineraries!
# trying - departure: NQZ, arrival: PEK
# error while processing NQZ-PEK: No itineraries!
# trying - departure: NQZ, arrival: LCA
# error while processing NQZ-LCA: No itineraries!
# trying - departure: NQZ, arrival: DIL
# error while processing NQZ-DIL: No itineraries!
# trying - departure: NQZ, arrival: TBS
# success
# trying - departure: NQZ, arrival: DEL
# error while processing NQZ-DEL: No itineraries!
# trying - departure: NQZ, arrival: CGK
# error while processing NQZ-CGK: No itineraries!
# trying - departure: NQZ, arrival: IKA
# success
# trying - departure: NQZ, arrival: BGW
# success
# trying - departure: NQZ, arrival: TLV
# success
# trying - departure: NQZ, arrival: NRT
# error while processing NQZ-NRT: No itineraries!
# trying - departure: NQZ, arrival: AMM
# success
# trying - departure: NQZ, arrival: KWI
# success
# trying - departure: NQZ, arrival: FRU
# success
# trying - departure: NQZ, arrival: VTE
# error while processing NQZ-VTE: No itineraries!
# trying - departure: NQZ, arrival: BEY
# success
# trying - departure: NQZ, arrival: KUL
# error while processing NQZ-KUL: No itineraries!
# trying - departure: NQZ, arrival: MLE
# error while processing NQZ-MLE: No itineraries!
# trying - departure: NQZ, arrival: UBN
# error while processing NQZ-UBN: No itineraries!
# trying - departure: NQZ, arrival: NYT
# error while processing NQZ-NYT: No itineraries!
# trying - departure: NQZ, arrival: KTM
# success
# trying - departure: NQZ, arrival: MCT
# success
# trying - departure: NQZ, arrival: ISB
# error while processing NQZ-ISB: No itineraries!
# trying - departure: NQZ, arrival: MNL
# error while processing NQZ-MNL: No itineraries!
# trying - departure: NQZ, arrival: DOH
# success
# trying - departure: NQZ, arrival: RUH
# success
# trying - departure: NQZ, arrival: SIN
# error while processing NQZ-SIN: No itineraries!
# trying - departure: NQZ, arrival: ICN
# error while processing NQZ-ICN: No itineraries!
# trying - departure: NQZ, arrival: CMB
# success
# trying - departure: NQZ, arrival: DAM
# error while processing NQZ-DAM: No itineraries!
# trying - departure: NQZ, arrival: TPE
# error while processing NQZ-TPE: No itineraries!
# trying - departure: NQZ, arrival: DYU
# error while processing NQZ-DYU: No itineraries!
# trying - departure: NQZ, arrival: BKK
# error while processing NQZ-BKK: No itineraries!
# trying - departure: NQZ, arrival: ESB
# success
# trying - departure: NQZ, arrival: ASB
# error while processing NQZ-ASB: No itineraries!
# trying - departure: NQZ, arrival: AUH
# success
# trying - departure: NQZ, arrival: TAS
# success
# trying - departure: NQZ, arrival: HAN
# error while processing NQZ-HAN: No itineraries!
# trying - departure: KWI, arrival: KBL
# error while processing KWI-KBL: No itineraries!
# trying - departure: KWI, arrival: EVN
# success
# trying - departure: KWI, arrival: GYD
# success
# trying - departure: KWI, arrival: BAH
# success
# trying - departure: KWI, arrival: DAC
# success
# trying - departure: KWI, arrival: BWN
# error while processing KWI-BWN: No itineraries!
# trying - departure: KWI, arrival: PNH
# error while processing KWI-PNH: No itineraries!
# trying - departure: KWI, arrival: PEK
# success
# trying - departure: KWI, arrival: LCA
# success
# trying - departure: KWI, arrival: DIL
# error while processing KWI-DIL: No itineraries!
# trying - departure: KWI, arrival: TBS
# success
# trying - departure: KWI, arrival: DEL
# success
# trying - departure: KWI, arrival: CGK
# success
# trying - departure: KWI, arrival: IKA
# success
# trying - departure: KWI, arrival: BGW
# success
# trying - departure: KWI, arrival: TLV
# success
# trying - departure: KWI, arrival: NRT
# error while processing KWI-NRT: No itineraries!
# trying - departure: KWI, arrival: AMM
# success
# trying - departure: KWI, arrival: NQZ
# success
# trying - departure: KWI, arrival: FRU
# success
# trying - departure: KWI, arrival: VTE
# error while processing KWI-VTE: No itineraries!
# trying - departure: KWI, arrival: BEY
# success
# trying - departure: KWI, arrival: KUL
# success
# trying - departure: KWI, arrival: MLE
# success
# trying - departure: KWI, arrival: UBN
# error while processing KWI-UBN: No itineraries!
# trying - departure: KWI, arrival: NYT
# error while processing KWI-NYT: No itineraries!
# trying - departure: KWI, arrival: KTM
# success
# trying - departure: KWI, arrival: MCT
# success
# trying - departure: KWI, arrival: ISB
# success
# trying - departure: KWI, arrival: MNL
# success
# trying - departure: KWI, arrival: DOH
# success
# trying - departure: KWI, arrival: RUH
# success
# trying - departure: KWI, arrival: SIN
# error while processing KWI-SIN: No itineraries!
# trying - departure: KWI, arrival: ICN
# error while processing KWI-ICN: No itineraries!
# trying - departure: KWI, arrival: CMB
# success
# trying - departure: KWI, arrival: DAM
# error while processing KWI-DAM: No itineraries!
# trying - departure: KWI, arrival: TPE
# error while processing KWI-TPE: No itineraries!
# trying - departure: KWI, arrival: DYU
# error while processing KWI-DYU: No itineraries!
# trying - departure: KWI, arrival: BKK
# success
# trying - departure: KWI, arrival: ESB
# success
# trying - departure: KWI, arrival: ASB
# error while processing KWI-ASB: No itineraries!
# trying - departure: KWI, arrival: AUH
# error while processing KWI-AUH: No itineraries!
# trying - departure: KWI, arrival: TAS
# success
# trying - departure: KWI, arrival: HAN
# error while processing KWI-HAN: No itineraries!
# trying - departure: FRU, arrival: KBL
# error while processing FRU-KBL: No itineraries!
# trying - departure: FRU, arrival: EVN
# success
# trying - departure: FRU, arrival: GYD
# success
# trying - departure: FRU, arrival: BAH
# success
# trying - departure: FRU, arrival: DAC
# error while processing FRU-DAC: No itineraries!
# trying - departure: FRU, arrival: BWN
# error while processing FRU-BWN: No itineraries!
# trying - departure: FRU, arrival: PNH
# error while processing FRU-PNH: No itineraries!
# trying - departure: FRU, arrival: PEK
# error while processing FRU-PEK: No itineraries!
# trying - departure: FRU, arrival: LCA
# error while processing FRU-LCA: No itineraries!
# trying - departure: FRU, arrival: DIL
# error while processing FRU-DIL: No itineraries!
# trying - departure: FRU, arrival: TBS
# success
# trying - departure: FRU, arrival: DEL
# success
# trying - departure: FRU, arrival: CGK
# error while processing FRU-CGK: No itineraries!
# trying - departure: FRU, arrival: IKA
# success
# trying - departure: FRU, arrival: BGW
# success
# trying - departure: FRU, arrival: TLV
# success
# trying - departure: FRU, arrival: NRT
# error while processing FRU-NRT: No itineraries!
# trying - departure: FRU, arrival: AMM
# success
# trying - departure: FRU, arrival: NQZ
# error while processing FRU-NQZ: No itineraries!
# trying - departure: FRU, arrival: KWI
# success
# trying - departure: FRU, arrival: VTE
# error while processing FRU-VTE: No itineraries!
# trying - departure: FRU, arrival: BEY
# success
# trying - departure: FRU, arrival: KUL
# error while processing FRU-KUL: No itineraries!
# trying - departure: FRU, arrival: MLE
# error while processing FRU-MLE: No itineraries!
# trying - departure: FRU, arrival: UBN
# success
# trying - departure: FRU, arrival: NYT
# error while processing FRU-NYT: No itineraries!
# trying - departure: FRU, arrival: KTM
# error while processing FRU-KTM: No itineraries!
# trying - departure: FRU, arrival: MCT
# success
# trying - departure: FRU, arrival: ISB
# error while processing FRU-ISB: No itineraries!
# trying - departure: FRU, arrival: MNL
# error while processing FRU-MNL: No itineraries!
# trying - departure: FRU, arrival: DOH
# success
# trying - departure: FRU, arrival: RUH
# success
# trying - departure: FRU, arrival: SIN
# error while processing FRU-SIN: No itineraries!
# trying - departure: FRU, arrival: ICN
# success
# trying - departure: FRU, arrival: CMB
# error while processing FRU-CMB: No itineraries!
# trying - departure: FRU, arrival: DAM
# error while processing FRU-DAM: No itineraries!
# trying - departure: FRU, arrival: TPE
# error while processing FRU-TPE: No itineraries!
# trying - departure: FRU, arrival: DYU
# error while processing FRU-DYU: No itineraries!
# trying - departure: FRU, arrival: BKK
# error while processing FRU-BKK: No itineraries!
# trying - departure: FRU, arrival: ESB
# error while processing FRU-ESB: No itineraries!
# trying - departure: FRU, arrival: ASB
# error while processing FRU-ASB: No itineraries!
# trying - departure: FRU, arrival: AUH
# success
# trying - departure: FRU, arrival: TAS
# error while processing FRU-TAS: No itineraries!
# trying - departure: FRU, arrival: HAN
# error while processing FRU-HAN: No itineraries!
# trying - departure: VTE, arrival: KBL
# error while processing VTE-KBL: No itineraries!
# trying - departure: VTE, arrival: EVN
# error while processing VTE-EVN: No itineraries!
# trying - departure: VTE, arrival: GYD
# error while processing VTE-GYD: No itineraries!
# trying - departure: VTE, arrival: BAH
# error while processing VTE-BAH: No itineraries!
# trying - departure: VTE, arrival: DAC
# error while processing VTE-DAC: No itineraries!
# trying - departure: VTE, arrival: BWN
# error while processing VTE-BWN: No itineraries!
# trying - departure: VTE, arrival: PNH
# success
# trying - departure: VTE, arrival: PEK
# error while processing VTE-PEK: No itineraries!
# trying - departure: VTE, arrival: LCA
# error while processing VTE-LCA: No itineraries!
# trying - departure: VTE, arrival: DIL
# error while processing VTE-DIL: No itineraries!
# trying - departure: VTE, arrival: TBS
# error while processing VTE-TBS: No itineraries!
# trying - departure: VTE, arrival: DEL
# error while processing VTE-DEL: No itineraries!
# trying - departure: VTE, arrival: CGK
# success
# trying - departure: VTE, arrival: IKA
# error while processing VTE-IKA: No itineraries!
# trying - departure: VTE, arrival: BGW
# error while processing VTE-BGW: No itineraries!
# trying - departure: VTE, arrival: TLV
# error while processing VTE-TLV: No itineraries!
# trying - departure: VTE, arrival: NRT
# success
# trying - departure: VTE, arrival: AMM
# error while processing VTE-AMM: No itineraries!
# trying - departure: VTE, arrival: NQZ
# error while processing VTE-NQZ: No itineraries!
# trying - departure: VTE, arrival: KWI
# error while processing VTE-KWI: No itineraries!
# trying - departure: VTE, arrival: FRU
# error while processing VTE-FRU: No itineraries!
# trying - departure: VTE, arrival: BEY
# error while processing VTE-BEY: No itineraries!
# trying - departure: VTE, arrival: KUL
# success
# trying - departure: VTE, arrival: MLE
# error while processing VTE-MLE: No itineraries!
# trying - departure: VTE, arrival: UBN
# error while processing VTE-UBN: No itineraries!
# trying - departure: VTE, arrival: NYT
# error while processing VTE-NYT: No itineraries!
# trying - departure: VTE, arrival: KTM
# error while processing VTE-KTM: No itineraries!
# trying - departure: VTE, arrival: MCT
# error while processing VTE-MCT: No itineraries!
# trying - departure: VTE, arrival: ISB
# error while processing VTE-ISB: No itineraries!
# trying - departure: VTE, arrival: MNL
# success
# trying - departure: VTE, arrival: DOH
# error while processing VTE-DOH: No itineraries!
# trying - departure: VTE, arrival: RUH
# error while processing VTE-RUH: No itineraries!
# trying - departure: VTE, arrival: SIN
# success
# trying - departure: VTE, arrival: ICN
# success
# trying - departure: VTE, arrival: CMB
# error while processing VTE-CMB: No itineraries!
# trying - departure: VTE, arrival: DAM
# error while processing VTE-DAM: No itineraries!
# trying - departure: VTE, arrival: TPE
# success
# trying - departure: VTE, arrival: DYU
# error while processing VTE-DYU: No itineraries!
# trying - departure: VTE, arrival: BKK
# success
# trying - departure: VTE, arrival: ESB
# error while processing VTE-ESB: No itineraries!
# trying - departure: VTE, arrival: ASB
# error while processing VTE-ASB: No itineraries!
# trying - departure: VTE, arrival: AUH
# error while processing VTE-AUH: No itineraries!
# trying - departure: VTE, arrival: TAS
# error while processing VTE-TAS: No itineraries!
# trying - departure: VTE, arrival: HAN
# success
# trying - departure: BEY, arrival: KBL
# error while processing BEY-KBL: No itineraries!
# trying - departure: BEY, arrival: EVN
# success
# trying - departure: BEY, arrival: GYD
# success
# trying - departure: BEY, arrival: BAH
# error while processing BEY-BAH: No itineraries!
# trying - departure: BEY, arrival: DAC
# error while processing BEY-DAC: No itineraries!
# trying - departure: BEY, arrival: BWN
# error while processing BEY-BWN: No itineraries!
# trying - departure: BEY, arrival: PNH
# error while processing BEY-PNH: No itineraries!
# trying - departure: BEY, arrival: PEK
# error while processing BEY-PEK: No itineraries!
# trying - departure: BEY, arrival: LCA
# success
# trying - departure: BEY, arrival: DIL
# error while processing BEY-DIL: No itineraries!
# trying - departure: BEY, arrival: TBS
# success
# trying - departure: BEY, arrival: DEL
# error while processing BEY-DEL: No itineraries!
# trying - departure: BEY, arrival: CGK
# error while processing BEY-CGK: No itineraries!
# trying - departure: BEY, arrival: IKA
# success
# trying - departure: BEY, arrival: BGW
# success
# trying - departure: BEY, arrival: TLV
# success
# trying - departure: BEY, arrival: NRT
# error while processing BEY-NRT: No itineraries!
# trying - departure: BEY, arrival: AMM
# success
# trying - departure: BEY, arrival: NQZ
# error while processing BEY-NQZ: No itineraries!
# trying - departure: BEY, arrival: KWI
# success
# trying - departure: BEY, arrival: FRU
# success
# trying - departure: BEY, arrival: VTE
# error while processing BEY-VTE: No itineraries!
# trying - departure: BEY, arrival: KUL
# error while processing BEY-KUL: No itineraries!
# trying - departure: BEY, arrival: MLE
# error while processing BEY-MLE: No itineraries!
# trying - departure: BEY, arrival: UBN
# error while processing BEY-UBN: No itineraries!
# trying - departure: BEY, arrival: NYT
# error while processing BEY-NYT: No itineraries!
# trying - departure: BEY, arrival: KTM
# error while processing BEY-KTM: No itineraries!
# trying - departure: BEY, arrival: MCT
# success
# trying - departure: BEY, arrival: ISB
# error while processing BEY-ISB: No itineraries!
# trying - departure: BEY, arrival: MNL
# error while processing BEY-MNL: No itineraries!
# trying - departure: BEY, arrival: DOH
# success
# trying - departure: BEY, arrival: RUH
# success
# trying - departure: BEY, arrival: SIN
# error while processing BEY-SIN: No itineraries!
# trying - departure: BEY, arrival: ICN
# error while processing BEY-ICN: No itineraries!
# trying - departure: BEY, arrival: CMB
# success
# trying - departure: BEY, arrival: DAM
# error while processing BEY-DAM: No itineraries!
# trying - departure: BEY, arrival: TPE
# error while processing BEY-TPE: No itineraries!
# trying - departure: BEY, arrival: DYU
# error while processing BEY-DYU: No itineraries!
# trying - departure: BEY, arrival: BKK
# error while processing BEY-BKK: No itineraries!
# trying - departure: BEY, arrival: ESB
# success
# trying - departure: BEY, arrival: ASB
# error while processing BEY-ASB: No itineraries!
# trying - departure: BEY, arrival: AUH
# success
# trying - departure: BEY, arrival: TAS
# success
# trying - departure: BEY, arrival: HAN
# error while processing BEY-HAN: No itineraries!
# trying - departure: KUL, arrival: KBL
# error while processing KUL-KBL: No itineraries!
# trying - departure: KUL, arrival: EVN
# error while processing KUL-EVN: No itineraries!
# trying - departure: KUL, arrival: GYD
# success
# trying - departure: KUL, arrival: BAH
# error while processing KUL-BAH: No itineraries!
# trying - departure: KUL, arrival: DAC
# success
# trying - departure: KUL, arrival: BWN
# success
# trying - departure: KUL, arrival: PNH
# success
# trying - departure: KUL, arrival: PEK
# success
# trying - departure: KUL, arrival: LCA
# error while processing KUL-LCA: No itineraries!
# trying - departure: KUL, arrival: DIL
# error while processing KUL-DIL: No itineraries!
# trying - departure: KUL, arrival: TBS
# error while processing KUL-TBS: No itineraries!
# trying - departure: KUL, arrival: DEL
# success
# trying - departure: KUL, arrival: CGK
# success
# trying - departure: KUL, arrival: IKA
# error while processing KUL-IKA: No itineraries!
# trying - departure: KUL, arrival: BGW
# error while processing KUL-BGW: No itineraries!
# trying - departure: KUL, arrival: TLV
# error while processing KUL-TLV: No itineraries!
# trying - departure: KUL, arrival: NRT
# success
# trying - departure: KUL, arrival: AMM
# success
# trying - departure: KUL, arrival: NQZ
# success
# trying - departure: KUL, arrival: KWI
# error while processing KUL-KWI: No itineraries!
# trying - departure: KUL, arrival: FRU
# error while processing KUL-FRU: No itineraries!
# trying - departure: KUL, arrival: VTE
# success
# trying - departure: KUL, arrival: BEY
# error while processing KUL-BEY: No itineraries!
# trying - departure: KUL, arrival: MLE
# success
# trying - departure: KUL, arrival: UBN
# error while processing KUL-UBN: No itineraries!
# trying - departure: KUL, arrival: NYT
# error while processing KUL-NYT: No itineraries!
# trying - departure: KUL, arrival: KTM
# error while processing KUL-KTM: No itineraries!
# trying - departure: KUL, arrival: MCT
# error while processing KUL-MCT: No itineraries!
# trying - departure: KUL, arrival: ISB
# success
# trying - departure: KUL, arrival: MNL
# success
# trying - departure: KUL, arrival: DOH
# error while processing KUL-DOH: No itineraries!
# trying - departure: KUL, arrival: RUH
# success
# trying - departure: KUL, arrival: SIN
# success
# trying - departure: KUL, arrival: ICN
# success
# trying - departure: KUL, arrival: CMB
# error while processing KUL-CMB: No itineraries!
# trying - departure: KUL, arrival: DAM
# error while processing KUL-DAM: No itineraries!
# trying - departure: KUL, arrival: TPE
# success
# trying - departure: KUL, arrival: DYU
# error while processing KUL-DYU: No itineraries!
# trying - departure: KUL, arrival: BKK
# success
# trying - departure: KUL, arrival: ESB
# success
# trying - departure: KUL, arrival: ASB
# error while processing KUL-ASB: No itineraries!
# trying - departure: KUL, arrival: AUH
# success
# trying - departure: KUL, arrival: TAS
# success
# trying - departure: KUL, arrival: HAN
# success
# trying - departure: MLE, arrival: KBL
# error while processing MLE-KBL: No itineraries!
# trying - departure: MLE, arrival: EVN
# error while processing MLE-EVN: No itineraries!
# trying - departure: MLE, arrival: GYD
# success
# trying - departure: MLE, arrival: BAH
# success
# trying - departure: MLE, arrival: DAC
# success
# trying - departure: MLE, arrival: BWN
# error while processing MLE-BWN: No itineraries!
# trying - departure: MLE, arrival: PNH
# error while processing MLE-PNH: No itineraries!
# trying - departure: MLE, arrival: PEK
# error while processing MLE-PEK: No itineraries!
# trying - departure: MLE, arrival: LCA
# error while processing MLE-LCA: No itineraries!
# trying - departure: MLE, arrival: DIL
# error while processing MLE-DIL: No itineraries!
# trying - departure: MLE, arrival: TBS
# error while processing MLE-TBS: No itineraries!
# trying - departure: MLE, arrival: DEL
# success
# trying - departure: MLE, arrival: CGK
# error while processing MLE-CGK: No itineraries!
# trying - departure: MLE, arrival: IKA
# error while processing MLE-IKA: No itineraries!
# trying - departure: MLE, arrival: BGW
# success
# trying - departure: MLE, arrival: TLV
# success
# trying - departure: MLE, arrival: NRT
# error while processing MLE-NRT: No itineraries!
# trying - departure: MLE, arrival: AMM
# success
# trying - departure: MLE, arrival: NQZ
# error while processing MLE-NQZ: No itineraries!
# trying - departure: MLE, arrival: KWI
# success
# trying - departure: MLE, arrival: FRU
# success
# trying - departure: MLE, arrival: VTE
# error while processing MLE-VTE: No itineraries!
# trying - departure: MLE, arrival: BEY
# success
# trying - departure: MLE, arrival: KUL
# success
# trying - departure: MLE, arrival: UBN
# error while processing MLE-UBN: No itineraries!
# trying - departure: MLE, arrival: NYT
# error while processing MLE-NYT: No itineraries!
# trying - departure: MLE, arrival: KTM
# success
# trying - departure: MLE, arrival: MCT
# success
# trying - departure: MLE, arrival: ISB
# error while processing MLE-ISB: No itineraries!
# trying - departure: MLE, arrival: MNL
# error while processing MLE-MNL: No itineraries!
# trying - departure: MLE, arrival: DOH
# error while processing MLE-DOH: No itineraries!
# trying - departure: MLE, arrival: RUH
# success
# trying - departure: MLE, arrival: SIN
# success
# trying - departure: MLE, arrival: ICN
# error while processing MLE-ICN: No itineraries!
# trying - departure: MLE, arrival: CMB
# success
# trying - departure: MLE, arrival: DAM
# error while processing MLE-DAM: No itineraries!
# trying - departure: MLE, arrival: TPE
# error while processing MLE-TPE: No itineraries!
# trying - departure: MLE, arrival: DYU
# error while processing MLE-DYU: No itineraries!
# trying - departure: MLE, arrival: BKK
# success
# trying - departure: MLE, arrival: ESB
# error while processing MLE-ESB: No itineraries!
# trying - departure: MLE, arrival: ASB
# error while processing MLE-ASB: No itineraries!
# trying - departure: MLE, arrival: AUH
# success
# trying - departure: MLE, arrival: TAS
# success
# trying - departure: MLE, arrival: HAN
# error while processing MLE-HAN: No itineraries!
# trying - departure: UBN, arrival: KBL
# error while processing UBN-KBL: No itineraries!
# trying - departure: UBN, arrival: EVN
# error while processing UBN-EVN: No itineraries!
# trying - departure: UBN, arrival: GYD
# error while processing UBN-GYD: No itineraries!
# trying - departure: UBN, arrival: BAH
# error while processing UBN-BAH: No itineraries!
# trying - departure: UBN, arrival: DAC
# error while processing UBN-DAC: No itineraries!
# trying - departure: UBN, arrival: BWN
# error while processing UBN-BWN: No itineraries!
# trying - departure: UBN, arrival: PNH
# error while processing UBN-PNH: No itineraries!
# trying - departure: UBN, arrival: PEK
# error while processing UBN-PEK: No itineraries!
# trying - departure: UBN, arrival: LCA
# error while processing UBN-LCA: No itineraries!
# trying - departure: UBN, arrival: DIL
# error while processing UBN-DIL: No itineraries!
# trying - departure: UBN, arrival: TBS
# error while processing UBN-TBS: No itineraries!
# trying - departure: UBN, arrival: DEL
# error while processing UBN-DEL: No itineraries!
# trying - departure: UBN, arrival: CGK
# error while processing UBN-CGK: No itineraries!
# trying - departure: UBN, arrival: IKA
# error while processing UBN-IKA: No itineraries!
# trying - departure: UBN, arrival: BGW
# error while processing UBN-BGW: No itineraries!
# trying - departure: UBN, arrival: TLV
# error while processing UBN-TLV: No itineraries!
# trying - departure: UBN, arrival: NRT
# error while processing UBN-NRT: No itineraries!
# trying - departure: UBN, arrival: AMM
# error while processing UBN-AMM: No itineraries!
# trying - departure: UBN, arrival: NQZ
# error while processing UBN-NQZ: No itineraries!
# trying - departure: UBN, arrival: KWI
# error while processing UBN-KWI: No itineraries!
# trying - departure: UBN, arrival: FRU
# error while processing UBN-FRU: No itineraries!
# trying - departure: UBN, arrival: VTE
# error while processing UBN-VTE: No itineraries!
# trying - departure: UBN, arrival: BEY
# error while processing UBN-BEY: No itineraries!
# trying - departure: UBN, arrival: KUL
# error while processing UBN-KUL: No itineraries!
# trying - departure: UBN, arrival: MLE
# error while processing UBN-MLE: No itineraries!
# trying - departure: UBN, arrival: NYT
# error while processing UBN-NYT: No itineraries!
# trying - departure: UBN, arrival: KTM
# error while processing UBN-KTM: No itineraries!
# trying - departure: UBN, arrival: MCT
# error while processing UBN-MCT: No itineraries!
# trying - departure: UBN, arrival: ISB
# error while processing UBN-ISB: No itineraries!
# trying - departure: UBN, arrival: MNL
# error while processing UBN-MNL: No itineraries!
# trying - departure: UBN, arrival: DOH
# error while processing UBN-DOH: No itineraries!
# trying - departure: UBN, arrival: RUH
# error while processing UBN-RUH: No itineraries!
# trying - departure: UBN, arrival: SIN
# error while processing UBN-SIN: No itineraries!
# trying - departure: UBN, arrival: ICN
# error while processing UBN-ICN: No itineraries!
# trying - departure: UBN, arrival: CMB
# error while processing UBN-CMB: No itineraries!
# trying - departure: UBN, arrival: DAM
# error while processing UBN-DAM: No itineraries!
# trying - departure: UBN, arrival: TPE
# error while processing UBN-TPE: No itineraries!
# trying - departure: UBN, arrival: DYU
# error while processing UBN-DYU: No itineraries!
# trying - departure: UBN, arrival: BKK
# error while processing UBN-BKK: No itineraries!
# trying - departure: UBN, arrival: ESB
# error while processing UBN-ESB: No itineraries!
# trying - departure: UBN, arrival: ASB
# error while processing UBN-ASB: No itineraries!
# trying - departure: UBN, arrival: AUH
# error while processing UBN-AUH: No itineraries!
# trying - departure: UBN, arrival: TAS
# error while processing UBN-TAS: No itineraries!
# trying - departure: UBN, arrival: HAN
# error while processing UBN-HAN: No itineraries!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 48
#      45         continue
#      47 # concat the dataframes
# ---> 48 combined_dataframe = pd.concat(dataframes, ignore_index=True)
#      49 #combine_to_datetime(combined_dataframe, 'arrival')
#      50 #combine_to_datetime(combined_dataframe, 'departure')
#      51
#      52 # save
#      53 combined_dataframe.to_csv(f'../Data/FlightAPIData/{timestamp}/{timestamp}_{departure}_flight_api_data.csv', index=False)
#
# File ~/miniconda3/envs/spring2023env/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/spring2023env/lib/python3.10/site-packages/pandas/core/reshape/concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File ~/miniconda3/envs/spring2023env/lib/python3.10/site-packages/pandas/core/reshape/concat.py:404, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     401     objs = list(objs)
#     403 if len(objs) == 0:
# --> 404     raise ValueError("No objects to concatenate")
#     406 if keys is None:
#     407     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate
