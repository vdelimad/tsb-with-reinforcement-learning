# %% [markdown]
# Libraries

# %%
import pandas as pd
import requests
from datetime import datetime
import time
import os
import json

# %% [markdown]
# Bring in data

# %%
capital_cities = pd.read_csv('../../Data/capital_cities_and_airports.csv')

display(capital_cities.shape)
display(capital_cities.head())
# Out:
# (43, 6)
#        country capital_city  capital_latitude  capital_longitude airport_iata  \
# 0  Afghanistan        Kabul           34.5167            69.1833          KBL
# 1      Armenia      Yerevan           40.1812            44.5136          EVN
# 2   Azerbaijan         Baku           40.3953            49.8622          GYD
# 3      Bahrain       Manama           26.2361            50.5831          BAH
# 4   Bangladesh        Dhaka           23.7231            90.4086          DAC
#
#                              airport_name
# 0      Hamid Karzai International Airport
# 1        Zvartnots International Airport
# 2     Heydar Aliyev International Airport
# 3           Bahrain International Airport
# 4  Hazrat Shahjalal International Airport

# %% [markdown]
# Helper functions

# %%
# format departure datetime
def combine_to_datetime(dataframe, direction):
    # combine the departure columns into a single datetime column
    dataframe[f'{direction}_datetime'] = pd.to_datetime(
        dataframe[f'{direction}_year'].astype(str) + '-' +
        dataframe[f'{direction}_month'].astype(str).str.zfill(2) + '-' +
        dataframe[f'{direction}_day'].astype(str).str.zfill(2) + ' ' +
        dataframe[f'{direction}_hour'].astype(str).str.zfill(2) + ':' +
        dataframe[f'{direction}_minute'].astype(str).str.zfill(2) + ':' +
        dataframe[f'{direction}_second'].astype(str).str.zfill(2)
    )
    
    # drop the original departure columns
    dataframe.drop([f'{direction}_day', f'{direction}_month', f'{direction}_year', f'{direction}_hour', f'{direction}_minute', f'{direction}_second'], axis=1, inplace=True)

# %% [markdown]
# ## Function setup and testing

# %% [markdown]
# Get data

# %%
# bring in key
with open('../../Data/skyscanner_auth.txt', 'r') as file:
    skyscanner_auth = file.read()

# %%
# set up api
def get_flight_tables(departure_airport, arrival_airport, year, month, day, skyscanner_auth=skyscanner_auth):
    url = 'https://partners.api.skyscanner.net/apiservices/v3/flights/live/search/create'
    headers = {'x-api-key': skyscanner_auth}

    data = {
        'query': {
            'market': 'US',
            'locale': 'en-US',
            'currency': 'USD',
            'query_legs': [{
                'origin_place_id': {'iata': departure_airport},
                'destination_place_id': {'iata': arrival_airport},
                'date': {'year': year, 'month': month, 'day': day}
            }],
            'adults': 1,
            'cabin_class': 'CABIN_CLASS_ECONOMY'
        }
    }
    
    try:
        response = requests.post(url, headers=headers, json=data)
        
        if response.status_code == 200:
            # store data
            response = response.json()
            #print(json.dumps(response, indent=4)

            return response['content']['results']
        else:
            response.raise_for_status()
    except requests.exceptions.HTTPError as err:
        print(err)

# test
flight_tables = get_flight_tables('NRT', 'TLV', 2023, 5, 22)

# %% [markdown]
# * Itineraries:	Bookable itinerary which corresponds with what was requested in the search. A return trip will consist of 2 legs, while a one-way trip will consist of 1 leg. An itinerary will contain a deepLink field which takes the traveler to the booking page.
# * Leg:	Includes details about the flight leg from destination to origin. A leg has 1 segment if it is a direct flight, and can have multiple segments if there are multiple stopovers.
# * Segment:	Shows the individual stops in a leg. I.e.: if a leg has 1 stop, the segment will show details about the stopover such as the length of time and where the stopover location is.
# * Places:	Shows the individual stops in a leg. I.e.: if a leg has 1 stop, the segment will show details about the stopover such as the length of time and where the stopover location is.
# * Carriers:	Similar to places, carriers contains information about the airlines referenced in itineraries.
# * Agents:	similar to places, agents contains information about the OTAs referenced in itineraries.
#
# https://developers.skyscanner.net/docs/flights-live-prices/overview

# %% [markdown]
# ### Itineraries

# %%
def clean_itineraries_table(flight_tables):
    
    # subset
    itineraries_dict = flight_tables['itineraries']
    # check if no itineraries
    if not itineraries_dict:
        raise Exception("No itineraries!")
    

    # format
    rows = []
    for key, value in itineraries_dict.items():
        for pricing_option in value['pricingOptions']:
            price = pricing_option['price']
            for item in pricing_option['items']:
                item_price = item['price']
                for fare in item['fares']:
                    rows.append({
                        'id': key,
                        'price_amount': price['amount'],
                        'price_unit': price['unit'],
                        'price_update_status': price['updateStatus'],
                        'agent_id': item['agentId'],
                        'deep_link': item['deepLink'],
                        'segment_id': fare['segmentId'],
                        'booking_code': fare['bookingCode'],
                        'fare_basis_code': fare['fareBasisCode'],
                        'transfer_type': pricing_option['transferType'],
                        'option_id': pricing_option['id']
                    })

    # create dataframe
    return pd.DataFrame(rows)


# test
itineraries = clean_itineraries_table(flight_tables)
display(itineraries.head())
# Out:
#                                                   id price_amount  \
# 0  14788-2305220915--31461,-32213,-31669-3-16995-...       619990
# 1  14788-2305220915--31461,-32213,-31669-3-16995-...       619990
# 2  14788-2305220915--31461,-32213,-31669-3-16995-...       619990
# 3  14788-2305220915--31461,-32213,-31669-3-16995-...       619990
# 4  14788-2305220930--31705,-32339,-31669-3-16995-...       560990
#
#          price_unit              price_update_status agent_id  \
# 0  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     arus
# 1  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     arus
# 2  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     arus
# 3  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     arus
# 4  PRICE_UNIT_MILLI  PRICE_UPDATE_STATUS_UNSPECIFIED     arus
#
#                                            deep_link  \
# 0  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 1  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 2  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 3  https://skyscanner.pxf.io/c/2850210/1103265/13...
# 4  https://skyscanner.pxf.io/c/2850210/1103265/13...
#
#                                  segment_id booking_code fare_basis_code  \
# 0   14788-9970-2305220915-2305221400--31461
# 1   9970-10075-2305221550-2305221835--32213
# 2   10075-9618-2305222215-2305222345--32213
# 3   9618-16995-2305230810-2305231050--31669
# 4  14788-12071-2305220930-2305221305--31705
#
#                            transfer_type     option_id
# 0  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  zHHIuQLaPs5_
# 1  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  zHHIuQLaPs5_
# 2  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  zHHIuQLaPs5_
# 3  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  zHHIuQLaPs5_
# 4  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER  eoOK74cBNpdU

# %% [markdown]
# ### Legs

# %%
def clean_legs_table(flight_tables):
    # subset
    legs_dict = flight_tables['legs']

    # format
    rows = []
    for key, value in legs_dict.items():
        departure_dt = value['departureDateTime']
        arrival_dt = value['arrivalDateTime']
        for segment_id, marketing_carrier_id, operating_carrier_id in zip(value['segmentIds'], value['marketingCarrierIds'], value['operatingCarrierIds']):
            rows.append({
                'id': key,
                'origin_place_id': value['originPlaceId'],
                'destination_place_id': value['destinationPlaceId'],
                'departure_year': departure_dt['year'],
                'departure_month': departure_dt['month'],
                'departure_day': departure_dt['day'],
                'departure_hour': departure_dt['hour'],
                'departure_minute': departure_dt['minute'],
                'departure_second': departure_dt['second'],
                'arrival_year': arrival_dt['year'],
                'arrival_month': arrival_dt['month'],
                'arrival_day': arrival_dt['day'],
                'arrival_hour': arrival_dt['hour'],
                'arrival_minute': arrival_dt['minute'],
                'arrival_second': arrival_dt['second'],
                'duration_minutes': value['durationInMinutes'],
                'stop_count': value['stopCount'],
                'marketing_carrier_id': marketing_carrier_id,
                'operating_carrier_id': operating_carrier_id,
                'segment_id': segment_id
            })

    # create dataframe
    legs = pd.DataFrame(rows)

    # combine time  columns
    combine_to_datetime(legs, 'departure')
    combine_to_datetime(legs, 'arrival')

    # rename id column
    return legs.rename(columns={'id': 'leg_id'})


# test
legs = clean_legs_table(flight_tables)
display(legs.head())
# Out:
#                                               leg_id origin_place_id  \
# 0  14788-2305220915--31461,-32213,-31669-3-16995-...       128668889
# 1  14788-2305220915--31461,-32213,-31669-3-16995-...       128668889
# 2  14788-2305220915--31461,-32213,-31669-3-16995-...       128668889
# 3  14788-2305220930--31705,-32339,-31669-3-16995-...       128668889
# 4  14788-2305220930--31705,-32339,-31669-3-16995-...       128668889
#
#   destination_place_id  duration_minutes  stop_count marketing_carrier_id  \
# 0             95673635              1895           3               -31461
# 1             95673635              1895           3               -32213
# 2             95673635              1895           3               -31669
# 3             95673635              1880           3               -31705
# 4             95673635              1880           3               -32339
#
#   operating_carrier_id                                segment_id  \
# 0               -31461   14788-9970-2305220915-2305221400--31461
# 1               -32213   9970-10075-2305221550-2305221835--32213
# 2               -32761   10075-9618-2305222215-2305222345--32213
# 3               -31705  14788-12071-2305220930-2305221305--31705
# 4               -32339  12071-10075-2305221820-2305222150--31705
#
#    departure_datetime    arrival_datetime
# 0 2023-05-22 09:15:00 2023-05-23 10:50:00
# 1 2023-05-22 09:15:00 2023-05-23 10:50:00
# 2 2023-05-22 09:15:00 2023-05-23 10:50:00
# 3 2023-05-22 09:30:00 2023-05-23 10:50:00
# 4 2023-05-22 09:30:00 2023-05-23 10:50:00

# %% [markdown]
# ### Segments

# %%
def clean_segments_table(flight_tables):
    # subset
    segments_dict = flight_tables['segments']

    # format
    rows = []
    for key, value in segments_dict.items():
        departure_dt = value['departureDateTime']
        arrival_dt = value['arrivalDateTime']

        rows.append({
            'id': key,
            'origin_place_id': value['originPlaceId'],
            'destination_place_id': value['destinationPlaceId'],
            'departure_year': departure_dt['year'],
            'departure_month': departure_dt['month'],
            'departure_day': departure_dt['day'],
            'departure_hour': departure_dt['hour'],
            'departure_minute': departure_dt['minute'],
            'departure_second': departure_dt['second'],
            'arrival_year': arrival_dt['year'],
            'arrival_month': arrival_dt['month'],
            'arrival_day': arrival_dt['day'],
            'arrival_hour': arrival_dt['hour'],
            'arrival_minute': arrival_dt['minute'],
            'arrival_second': arrival_dt['second'],
            'duration_minutes': value['durationInMinutes'],
            'marketing_flight_number': value['marketingFlightNumber'],
            'marketing_carrier_id': value['marketingCarrierId'],
            'operating_carrier_id': value['operatingCarrierId']
        })


    # create dataframe
    segments = pd.DataFrame(rows)

    # combine time columns
    combine_to_datetime(segments, 'departure')
    combine_to_datetime(segments, 'arrival')

    # rename id column
    return segments.rename(columns={'id': 'segment_id'})


# test
segments = clean_segments_table(flight_tables)
display(segments.head())
# Out:
#                                  segment_id origin_place_id  \
# 0   10075-9618-2305222215-2305222345--32213        95673320
# 1   10075-9618-2305230445-2305230610--32339        95673320
# 2  11182-16995-2305230705-2305230935--32348        95673506
# 3  12071-10075-2305221820-2305222150--31705       128668079
# 4  12191-16995-2305230220-2305230745--32456       128668132
#
#   destination_place_id  duration_minutes marketing_flight_number  \
# 0             95673509               180                    1401
# 1             95673509               175                     205
# 2             95673635               210                    2369
# 3             95673320               300                     907
# 4             95673635               625                     675
#
#   marketing_carrier_id operating_carrier_id  departure_datetime  \
# 0               -32213               -32213 2023-05-22 22:15:00
# 1               -32339               -32339 2023-05-23 04:45:00
# 2               -32348               -32301 2023-05-23 07:05:00
# 3               -31705               -31705 2023-05-22 18:20:00
# 4               -32456               -32456 2023-05-23 02:20:00
#
#      arrival_datetime
# 0 2023-05-22 23:45:00
# 1 2023-05-23 06:10:00
# 2 2023-05-23 09:35:00
# 3 2023-05-22 21:50:00
# 4 2023-05-23 07:45:00

# %% [markdown]
# ### Places

# %%
def clean_places_table(flight_tables):
    # subset
    places_dict = flight_tables['places']

    # format
    rows = []
    for key, value in places_dict.items():
        rows.append({
            'entity_id': value['entityId'],
            'parent_id': value['parentId'],
            'name': value['name'],
            'place_type': value['type'],
            'iata': value['iata'],
            'coordinates': value['coordinates']
        })


    # create dataframe
    return pd.DataFrame(rows)


# test
places = clean_places_table(flight_tables)
display(places.head())
# Out:
#    entity_id parent_id            name          place_type iata coordinates
# 0  128668079  27541992           Hanoi  PLACE_TYPE_AIRPORT  HAN        None
# 1  128668132  27542065  Hong Kong Intl  PLACE_TYPE_AIRPORT  HKG        None
# 2  128668203  27536445     Addis Ababa  PLACE_TYPE_AIRPORT  ADD        None
# 3  128668889  27542089    Tokyo Narita  PLACE_TYPE_AIRPORT  NRT        None
# 4   27536445  29475224     Addis Ababa     PLACE_TYPE_CITY  ADD        None

# %% [markdown]
# ### Carriers

# %%
def clean_carriers_table(flight_tables):
    # subset
    carriers_dict = flight_tables['carriers']

    # format
    rows = []
    for key, value in carriers_dict.items():
        rows.append({
            'carrier_id': key,
            'name': value['name'],
            'alliance_id': value['allianceId'],
            'image_url': value['imageUrl'],
            'iata': value['iata']
        })



    # create dataframe
    return pd.DataFrame(rows)


# test
carriers = clean_carriers_table(flight_tables)
display(carriers.head())
# Out:
#   carrier_id              name alliance_id  \
# 0     -30816            Zipair
# 1     -31461    Thai AirAsia X
# 2     -31669          Wizz Air
# 3     -31705       VietJet Air
# 4     -31734  Turkish Airlines      -31999
#
#                                           image_url iata
# 0  https://logos.skyscnr.com/images/airlines/_Z.png   ZG
# 1  https://logos.skyscnr.com/images/airlines/XD.png   XJ
# 2  https://logos.skyscnr.com/images/airlines/WZ.png   W6
# 3  https://logos.skyscnr.com/images/airlines/4V.png   VJ
# 4  https://logos.skyscnr.com/images/airlines/TK.png   TK

# %% [markdown]
# ### Agents

# %%
def clean_agents_table(flight_tables):
    # subset
    agents_dict = flight_tables['agents']

    # format
    rows = []
    for key, value in agents_dict.items():
        rating_breakdown = value.get('ratingBreakdown') or {}
        rows.append({
            'agent_id': key,
            'name': value['name'],
            'agent_type': value['type'],
            'image_url': value['imageUrl'],
            'feedback_count': value['feedbackCount'],
            'rating': value['rating'],
            'customer_service': rating_breakdown.get('customerService', None),
            'reliable_prices': rating_breakdown.get('reliablePrices', None),
            'clear_extra_fees': rating_breakdown.get('clearExtraFees', None),
            'ease_of_booking': rating_breakdown.get('easeOfBooking', None),
            'other': rating_breakdown.get('other', None),
            'is_optimised_for_mobile': value['isOptimisedForMobile']
        })

    # create dataframe
    return pd.DataFrame(rows)


# test
agents = clean_agents_table(flight_tables)
display(agents.head())
# Out:
#   agent_id               name               agent_type  \
# 0     airf         Air France       AGENT_TYPE_AIRLINE
# 1     arus             Mytrip  AGENT_TYPE_TRAVEL_AGENT
# 2     ausa  Austrian Airlines       AGENT_TYPE_AIRLINE
# 3     bcom        Booking.com  AGENT_TYPE_TRAVEL_AGENT
# 4     bfus           Bravofly  AGENT_TYPE_TRAVEL_AGENT
#
#                                            image_url  feedback_count  rating  \
# 0  https://logos.skyscnr.com/images/websites/airf...            1903    2.87
# 1  https://logos.skyscnr.com/images/websites/arus...            8424    3.25
# 2  https://logos.skyscnr.com/images/websites/ausa...             364    3.75
# 3  https://logos.skyscnr.com/images/websites/bcom...            4381    3.62
# 4  https://logos.skyscnr.com/images/websites/bfus...            2773    2.62
#
#    customer_service  reliable_prices  clear_extra_fees  ease_of_booking  \
# 0          5.000000         1.668960          4.141784         2.992648
# 1          4.856892         3.538052          4.064076         3.325836
# 2          5.000000         3.303972          4.537448         3.612340
# 3          4.983912         3.188784          4.415532         3.849500
# 4          4.711384         2.962752          3.976468         1.484060
#
#       other  is_optimised_for_mobile
# 0  2.687180                     True
# 1  2.217688                     True
# 2  3.535248                     True
# 3  3.050716                     True
# 4  2.339328                     True

# %% [markdown]
# ### Alliances

# %%
def clean_alliances_table(flight_tables):
    # subset
    alliances_dict = flight_tables['alliances']

    # format
    rows = []
    for key, value in alliances_dict.items():
        rows.append({
            'alliance_id': key,
            'name': value['name']
        })

    # create dataframe
    return pd.DataFrame(rows)


# test
alliances = clean_alliances_table(flight_tables)
display(alliances.head())
# Out:
#   alliance_id           name
# 0      -31999  Star Alliance
# 1      -32000       OneWorld

# %% [markdown]
# ### Combine

# %%
def create_full_journey_table(departure_airport, arrival_airport, itineraries_table, agents_table, segments_table, carriers_table, places_table):
    
    trips_df = itineraries_table
    
    # sort by id
    #trips_df = itineraries_table.sort_values(by="id", ascending=True)
    #trips_df = trips_df.sort_values(by="price_amount", ascending=True)
    
    # temp column to preserve order
    # Add a temporary column to store the original index
    trips_df['temp_index'] = trips_df.index
    
    
    # price to float
    trips_df['price_amount'] = trips_df['price_amount'].astype(float)

    # drop unecesary columns
    trips_df = trips_df.drop(['deep_link', 'option_id', 'booking_code', 'fare_basis_code', 'price_update_status'], axis=1)


    # bring in the agent name
    trips_df = pd.merge(trips_df, agents_table[['agent_id', 'name']], on='agent_id')
    trips_df = trips_df.rename(columns={'name': 'agent_name'})
    trips_df = trips_df.drop('agent_id', axis=1)

    # bring in segment info
    trips_df = pd.merge(trips_df, segments_table, on='segment_id')

    # get carrier names
    trips_df = pd.merge(trips_df, carriers_table[['carrier_id', 'name']], left_on='marketing_carrier_id', right_on='carrier_id')
    trips_df = trips_df.rename(columns={'name': 'marketing_carrier_name'})
    trips_df = pd.merge(trips_df, carriers_table[['carrier_id', 'name']], left_on='operating_carrier_id', right_on='carrier_id')
    trips_df = trips_df.rename(columns={'name': 'operating_carrier_name'})
    trips_df = trips_df.drop(['marketing_carrier_id', 'operating_carrier_id', 'carrier_id_x', 'carrier_id_y'], axis=1)

    # bring in places
    trips_df = pd.merge(trips_df, places_table[['entity_id', 'name', 'iata']], left_on='origin_place_id', right_on='entity_id')
    trips_df = trips_df.rename(columns={'name': 'origin_place_name', 'iata': 'origin_place_iata' })
    trips_df = pd.merge(trips_df, places_table[['entity_id', 'name', 'iata']], left_on='destination_place_id', right_on='entity_id')
    trips_df = trips_df.rename(columns={'name': 'destination_place_name', 'iata': 'destination_place_iata'})
    trips_df = trips_df.drop(['origin_place_id', 'destination_place_id', 'entity_id_x', 'entity_id_y'], axis=1)

    # results don't only show airports requested, remove unrequested airports
    #trips_df = trips_df[trips_df['origin_place_iata'] == departure_airport]
    #trips_df = trips_df[trips_df['destination_place_iata'] == arrival_airport]
    
    # sort and drop temp column
    # Sort the merged DataFrame based on the temporary column
    trips_df = trips_df.sort_values('temp_index')

    # Drop the temporary column
    trips_df = trips_df.drop('temp_index', axis=1)
    
    #trips_df = trips_df.sort_values(by=['price_amount', 'id'], ascending=[True, True])

    return trips_df


# test
trips_df = create_full_journey_table('NRT', 'TPE', itineraries, agents, segments, carriers, places)
display(trips_df.head())
# Out:
#                                                    id  price_amount  \
# 0   14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 11  14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 23  14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 15  14788-2305220915--31461,-32213,-31669-3-16995-...      619990.0
# 4   14788-2305220930--31705,-32339,-31669-3-16995-...      560990.0
#
#           price_unit                                segment_id  \
# 0   PRICE_UNIT_MILLI   14788-9970-2305220915-2305221400--31461
# 11  PRICE_UNIT_MILLI   9970-10075-2305221550-2305221835--32213
# 23  PRICE_UNIT_MILLI   10075-9618-2305222215-2305222345--32213
# 15  PRICE_UNIT_MILLI   9618-16995-2305230810-2305231050--31669
# 4   PRICE_UNIT_MILLI  14788-12071-2305220930-2305221305--31705
#
#                             transfer_type agent_name  duration_minutes  \
# 0   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               405
# 11  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               255
# 23  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               180
# 15  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               220
# 4   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               335
#
#    marketing_flight_number  departure_datetime    arrival_datetime  \
# 0                      601 2023-05-22 09:15:00 2023-05-22 14:00:00
# 11                    1052 2023-05-22 15:50:00 2023-05-22 18:35:00
# 23                    1401 2023-05-22 22:15:00 2023-05-22 23:45:00
# 15                    7085 2023-05-23 08:10:00 2023-05-23 10:50:00
# 4                      933 2023-05-22 09:30:00 2023-05-22 13:05:00
#
#    marketing_carrier_name operating_carrier_name        origin_place_name  \
# 0          Thai AirAsia X         Thai AirAsia X             Tokyo Narita
# 11                 IndiGo                 IndiGo     Bangkok Suvarnabhumi
# 23                 IndiGo                 IndiGo                   Mumbai
# 15               Wizz Air     Wizz Air Abu Dhabi  Abu Dhabi International
# 4             VietJet Air            VietJet Air             Tokyo Narita
#
#    origin_place_iata   destination_place_name destination_place_iata
# 0                NRT     Bangkok Suvarnabhumi                    BKK
# 11               BKK                   Mumbai                    BOM
# 23               BOM  Abu Dhabi International                    AUH
# 15               AUH          Ben Gurion Intl                    TLV
# 4                NRT                    Hanoi                    HAN

# %% [markdown]
# ### Single function

# %%
# set departure and arrival airports
departure_airport = 'NRT'
arrival_airport = 'TLV'

def get_flight_data(departure_airport, arrival_airport, year, month, day):

    flight_tables = get_flight_tables(departure_airport, arrival_airport, year, month, day)

    itineraries_table = clean_itineraries_table(flight_tables)
    agents_table = clean_agents_table(flight_tables)
    segments_table = clean_segments_table(flight_tables)
    carriers_table = clean_carriers_table(flight_tables)
    places_table =clean_places_table(flight_tables)

    return create_full_journey_table(departure_airport, arrival_airport, itineraries_table, agents_table, segments_table, carriers_table, places_table)

get_flight_data(departure_airport, arrival_airport, 2023, 5, 22)
# Out:
#                                                    id  price_amount  \
# 0   14788-2305220915--31461,-32213,-31669-3-16995-...      624990.0
# 10  14788-2305220915--31461,-32213,-31669-3-16995-...      624990.0
# 21  14788-2305220915--31461,-32213,-31669-3-16995-...      624990.0
# 13  14788-2305220915--31461,-32213,-31669-3-16995-...      624990.0
# 3   14788-2305220920--32128,-32213,-31669-3-16995-...      630990.0
# 23  14788-2305220920--32128,-32213,-31669-3-16995-...      630990.0
# 22  14788-2305220920--32128,-32213,-31669-3-16995-...      630990.0
# 14  14788-2305220920--32128,-32213,-31669-3-16995-...      630990.0
# 5          14788-2305221035--31734-1-16995-2305222155     1041990.0
# 15         14788-2305221035--31734-1-16995-2305222155     1041990.0
# 1   14788-2305221445--31461,-32352-1-16995-2305230445      918900.0
# 11  14788-2305221445--31461,-32352-1-16995-2305230445      918900.0
# 2   14788-2305221700--30816,-32352-1-16995-2305230445      895900.0
# 12  14788-2305221700--30816,-32352-1-16995-2305230445      895900.0
# 7          14788-2305221715--32456-1-16995-2305230745     1031800.0
# 18         14788-2305221715--32456-1-16995-2305230745     1031800.0
# 8          14788-2305221830--32456-1-16995-2305230745     1142990.0
# 19         14788-2305221830--32456-1-16995-2305230745     1142990.0
# 4          14788-2305222115--32340-2-16995-2305231435      609990.0
# 24         14788-2305222115--32340-2-16995-2305231435      609990.0
# 16         14788-2305222115--32340-2-16995-2305231435      609990.0
# 9          14788-2305222150--32093-1-16995-2305231850      758900.0
# 20         14788-2305222150--32093-1-16995-2305231850      758900.0
# 6          14788-2305222230--32348-1-16995-2305230935     1080000.0
# 17         14788-2305222230--32348-1-16995-2305230935     1080000.0
#
#           price_unit                                segment_id  \
# 0   PRICE_UNIT_MILLI   14788-9970-2305220915-2305221400--31461
# 10  PRICE_UNIT_MILLI   9970-10075-2305221550-2305221835--32213
# 21  PRICE_UNIT_MILLI   10075-9618-2305222215-2305222345--32213
# 13  PRICE_UNIT_MILLI   9618-16995-2305230810-2305231050--31669
# 3   PRICE_UNIT_MILLI  14788-12409-2305220920-2305221145--32128
# 23  PRICE_UNIT_MILLI  12409-10957-2305221300-2305221805--32128
# 22  PRICE_UNIT_MILLI   10957-9618-2305222115-2305222325--32213
# 14  PRICE_UNIT_MILLI   9618-16995-2305230810-2305231050--31669
# 5   PRICE_UNIT_MILLI  14788-12585-2305221035-2305221750--31734
# 15  PRICE_UNIT_MILLI  12585-16995-2305221950-2305222155--31734
# 1   PRICE_UNIT_MILLI   14788-9970-2305221445-2305221935--31461
# 11  PRICE_UNIT_MILLI   9970-16995-2305222355-2305230445--32352
# 2   PRICE_UNIT_MILLI   14788-9970-2305221700-2305222145--30816
# 12  PRICE_UNIT_MILLI   9970-16995-2305222355-2305230445--32352
# 7   PRICE_UNIT_MILLI  14788-12191-2305221715-2305222120--32456
# 18  PRICE_UNIT_MILLI  12191-16995-2305230220-2305230745--32456
# 8   PRICE_UNIT_MILLI  14788-12191-2305221830-2305222225--32456
# 19  PRICE_UNIT_MILLI  12191-16995-2305230220-2305230745--32456
# 4   PRICE_UNIT_MILLI  14788-12409-2305222115-2305222355--32340
# 24  PRICE_UNIT_MILLI   12409-9252-2305230105-2305230705--32340
# 16  PRICE_UNIT_MILLI   9252-16995-2305231000-2305231435--32340
# 9   PRICE_UNIT_MILLI  14788-17648-2305222150-2305230540--32093
# 20  PRICE_UNIT_MILLI  17648-16995-2305231400-2305231850--32093
# 6   PRICE_UNIT_MILLI  14788-11182-2305222230-2305230445--32348
# 17  PRICE_UNIT_MILLI  11182-16995-2305230705-2305230935--32348
#
#                             transfer_type     agent_name  duration_minutes  \
# 0   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               405
# 10  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               255
# 21  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               180
# 13  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               220
# 3   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               145
# 23  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               515
# 22  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               220
# 14  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER         Mytrip               220
# 5                   TRANSFER_TYPE_MANAGED  FlightNetwork               795
# 15                  TRANSFER_TYPE_MANAGED  FlightNetwork               125
# 1   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               410
# 11  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               530
# 2   TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               405
# 12  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER       Trip.com               530
# 7                   TRANSFER_TYPE_MANAGED     SmartFares               305
# 18                  TRANSFER_TYPE_MANAGED     SmartFares               625
# 8                   TRANSFER_TYPE_MANAGED       GotoGate               295
# 19                  TRANSFER_TYPE_MANAGED       GotoGate               625
# 4                   TRANSFER_TYPE_MANAGED  FlightNetwork               160
# 24                  TRANSFER_TYPE_MANAGED  FlightNetwork               720
# 16                  TRANSFER_TYPE_MANAGED  FlightNetwork               275
# 9                   TRANSFER_TYPE_MANAGED     SmartFares               890
# 20                  TRANSFER_TYPE_MANAGED     SmartFares               230
# 6                   TRANSFER_TYPE_MANAGED       Trip.com               675
# 17                  TRANSFER_TYPE_MANAGED       Trip.com               210
#
#    marketing_flight_number  departure_datetime    arrival_datetime  \
# 0                      601 2023-05-22 09:15:00 2023-05-22 14:00:00
# 10                    1052 2023-05-22 15:50:00 2023-05-22 18:35:00
# 21                    1401 2023-05-22 22:15:00 2023-05-22 23:45:00
# 13                    7085 2023-05-23 08:10:00 2023-05-23 10:50:00
# 3                      706 2023-05-22 09:20:00 2023-05-22 11:45:00
# 23                     497 2023-05-22 13:00:00 2023-05-22 18:05:00
# 22                    1405 2023-05-22 21:15:00 2023-05-22 23:25:00
# 14                    7085 2023-05-23 08:10:00 2023-05-23 10:50:00
# 5                       51 2023-05-22 10:35:00 2023-05-22 17:50:00
# 15                     864 2023-05-22 19:50:00 2023-05-22 21:55:00
# 1                      603 2023-05-22 14:45:00 2023-05-22 19:35:00
# 11                      82 2023-05-22 23:55:00 2023-05-23 04:45:00
# 2                       51 2023-05-22 17:00:00 2023-05-22 21:45:00
# 12                      82 2023-05-22 23:55:00 2023-05-23 04:45:00
# 7                      521 2023-05-22 17:15:00 2023-05-22 21:20:00
# 18                     675 2023-05-23 02:20:00 2023-05-23 07:45:00
# 8                      505 2023-05-22 18:30:00 2023-05-22 22:25:00
# 19                     675 2023-05-23 02:20:00 2023-05-23 07:45:00
# 4                      673 2023-05-22 21:15:00 2023-05-22 23:55:00
# 24                     673 2023-05-23 01:05:00 2023-05-23 07:05:00
# 16                     418 2023-05-23 10:00:00 2023-05-23 14:35:00
# 9                       80 2023-05-22 21:50:00 2023-05-23 05:40:00
# 20                     155 2023-05-23 14:00:00 2023-05-23 18:50:00
# 6                      319 2023-05-22 22:30:00 2023-05-23 04:45:00
# 17                    2369 2023-05-23 07:05:00 2023-05-23 09:35:00
#
#    marketing_carrier_name operating_carrier_name  \
# 0          Thai AirAsia X         Thai AirAsia X
# 10                 IndiGo                 IndiGo
# 21                 IndiGo                 IndiGo
# 13               Wizz Air     Wizz Air Abu Dhabi
# 3              Korean Air             Korean Air
# 23             Korean Air             Korean Air
# 22                 IndiGo                 IndiGo
# 14               Wizz Air     Wizz Air Abu Dhabi
# 5        Turkish Airlines       Turkish Airlines
# 15       Turkish Airlines       Turkish Airlines
# 1          Thai AirAsia X         Thai AirAsia X
# 11  EL AL Israel Airlines  EL AL Israel Airlines
# 2                  Zipair                 Zipair
# 12  EL AL Israel Airlines  EL AL Israel Airlines
# 7          Cathay Pacific         Cathay Pacific
# 18         Cathay Pacific         Cathay Pacific
# 8          Cathay Pacific         Cathay Pacific
# 19         Cathay Pacific         Cathay Pacific
# 4      Ethiopian Airlines     Ethiopian Airlines
# 24     Ethiopian Airlines     Ethiopian Airlines
# 16     Ethiopian Airlines     Ethiopian Airlines
# 9                     LOT                    LOT
# 20                    LOT                    LOT
# 6                Emirates               Emirates
# 17               Emirates               flydubai
#
#                 origin_place_name origin_place_iata  \
# 0                    Tokyo Narita               NRT
# 10           Bangkok Suvarnabhumi               BKK
# 21                         Mumbai               BOM
# 13        Abu Dhabi International               AUH
# 3                    Tokyo Narita               NRT
# 23  Incheon International Airport               ICN
# 22   Indira Gandhi International                DEL
# 14        Abu Dhabi International               AUH
# 5                    Tokyo Narita               NRT
# 15                       Istanbul               IST
# 1                    Tokyo Narita               NRT
# 11           Bangkok Suvarnabhumi               BKK
# 2                    Tokyo Narita               NRT
# 12           Bangkok Suvarnabhumi               BKK
# 7                    Tokyo Narita               NRT
# 18                 Hong Kong Intl               HKG
# 8                    Tokyo Narita               NRT
# 19                 Hong Kong Intl               HKG
# 4                    Tokyo Narita               NRT
# 24  Incheon International Airport               ICN
# 16                    Addis Ababa               ADD
# 9                    Tokyo Narita               NRT
# 20                  Warsaw Chopin               WAW
# 6                    Tokyo Narita               NRT
# 17                          Dubai               DXB
#
#            destination_place_name destination_place_iata
# 0            Bangkok Suvarnabhumi                    BKK
# 10                         Mumbai                    BOM
# 21        Abu Dhabi International                    AUH
# 13                Ben Gurion Intl                    TLV
# 3   Incheon International Airport                    ICN
# 23   Indira Gandhi International                     DEL
# 22        Abu Dhabi International                    AUH
# 14                Ben Gurion Intl                    TLV
# 5                        Istanbul                    IST
# 15                Ben Gurion Intl                    TLV
# 1            Bangkok Suvarnabhumi                    BKK
# 11                Ben Gurion Intl                    TLV
# 2            Bangkok Suvarnabhumi                    BKK
# 12                Ben Gurion Intl                    TLV
# 7                  Hong Kong Intl                    HKG
# 18                Ben Gurion Intl                    TLV
# 8                  Hong Kong Intl                    HKG
# 19                Ben Gurion Intl                    TLV
# 4   Incheon International Airport                    ICN
# 24                    Addis Ababa                    ADD
# 16                Ben Gurion Intl                    TLV
# 9                   Warsaw Chopin                    WAW
# 20                Ben Gurion Intl                    TLV
# 6                           Dubai                    DXB
# 17                Ben Gurion Intl                    TLV

# %% [markdown]
# ## Gather the data

# %%
# iata code list
iata_codes_list = capital_cities['airport_iata'].tolist()
#iata_codes_list[:5]
iata_codes_list
# Out:
# ['KBL',
#  'EVN',
#  'GYD',
#  'BAH',
#  'DAC',
#  'BWN',
#  'PNH',
#  'PEK',
#  'LCA',
#  'DIL',
#  'TBS',
#  'DEL',
#  'CGK',
#  'IKA',
#  'BGW',
#  'TLV',
#  'NRT',
#  'AMM',
#  'NQZ',
#  'KWI',
#  'FRU',
#  'VTE',
#  'BEY',
#  'KUL',
#  'MLE',
#  'UBN',
#  'KTM',
#  'MCT',
#  'ISB',
#  'MNL',
#  'DOH',
#  'RUH',
#  'SIN',
#  'ICN',
#  'CMB',
#  'TPE',
#  'DYU',
#  'BKK',
#  'ESB',
#  'ASB',
#  'AUH',
#  'TAS',
#  'HAN']

# %%
# get airport pairs without departing and arriving at same place
airport_pairs = [(iata_codes_list[i], iata_codes_list[j]) for i in range(len(iata_codes_list)) for j in range(len(iata_codes_list)) if i != j]

#stats
display(f'number of airport: {len(iata_codes_list)}')
display(f'size of matrix entries without diagonal: {len(airport_pairs)}')
# Out:
# 'number of airport: 43'
# 'size of matrix entries without diagonal: 1806'

# %%
# timestamp so all files have the same time
timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
#timestamp = ''

timestamped_directory = f'../../Data/FlightAPIData/{timestamp}/'
if not os.path.exists(timestamped_directory):
    os.makedirs(timestamped_directory)

time_sleep_sec = 2
year = 2023
month = 5
day = 22

for departure in iata_codes_list:


    # leave out airports if needed
    #if departure in ['KBL', 'EVN', 'GYD', 'BAH', 'DAC', 'DAC','BWN','PNH','PEK', 'LCA', 'DIL', 'TBS', 'DEL', 'CGK', 'IKA', 'BGW','TLV','NRT','AMM','NQZ','KWI','FRU','VTE','BEY','KUL','MLE', 'UBN', 'KTM','MCT','ISB','MNL','DOH','RUH','SIN','ICN','CMB','TPE', 'DYU', 'BKK', 'ESB', 'ASB', 'AUH', 'TAS', 'HAN']:
    #    continue
    
    # init empty list
    dataframes = []
    
    for arrival in iata_codes_list:
        
        # skip if departure and arrival airport are the same
        if departure == arrival:
            continue
        
        
        try:
            print(f'trying - departure: {departure}, arrival: {arrival}')
            df = get_flight_data(departure, arrival, year, month, day)
            df['departure_query'] = departure
            df['arrival_query'] = arrival
            dataframes.append(df)
            print('success')
            
            # sleep to avoid hitting the api limit
            time.sleep(time_sleep_sec)
        except Exception as e:
            print(f"error while processing {departure}-{arrival}: {e}")
            # sleep to avoid hitting the api limit
            time.sleep(time_sleep_sec)
            continue
    
    # concat the dataframes
    combined_dataframe = pd.concat(dataframes, ignore_index=True)
    #combine_to_datetime(combined_dataframe, 'arrival')
    #combine_to_datetime(combined_dataframe, 'departure')

    # save
    combined_dataframe.to_csv(f'../../Data/FlightAPIData/{timestamp}/{timestamp}_{departure}_flight_api_data.csv', index=False)

# show
display(combined_dataframe.head())
# Out:
# trying - departure: ASB, arrival: KBL
# error while processing ASB-KBL: No itineraries!
# trying - departure: ASB, arrival: EVN
# success
# trying - departure: ASB, arrival: GYD
# success
# trying - departure: ASB, arrival: BAH
# success
# trying - departure: ASB, arrival: DAC
# success
# trying - departure: ASB, arrival: BWN
# success
# trying - departure: ASB, arrival: PNH
# success
# trying - departure: ASB, arrival: PEK
# success
# trying - departure: ASB, arrival: LCA
# success
# trying - departure: ASB, arrival: DIL
# success
# trying - departure: ASB, arrival: TBS
# success
# trying - departure: ASB, arrival: DEL
# success
# trying - departure: ASB, arrival: CGK
# success
# trying - departure: ASB, arrival: IKA
# success
# trying - departure: ASB, arrival: BGW
# success
# trying - departure: ASB, arrival: TLV
# success
# trying - departure: ASB, arrival: NRT
# success
# trying - departure: ASB, arrival: AMM
# success
# trying - departure: ASB, arrival: NQZ
# success
# trying - departure: ASB, arrival: KWI
# success
# trying - departure: ASB, arrival: FRU
# success
# trying - departure: ASB, arrival: VTE
# success
# trying - departure: ASB, arrival: BEY
# success
# trying - departure: ASB, arrival: KUL
# success
# trying - departure: ASB, arrival: MLE
# success
# trying - departure: ASB, arrival: UBN
# success
# trying - departure: ASB, arrival: KTM
# success
# trying - departure: ASB, arrival: MCT
# success
# trying - departure: ASB, arrival: ISB
# success
# trying - departure: ASB, arrival: MNL
# success
# trying - departure: ASB, arrival: DOH
# success
# trying - departure: ASB, arrival: RUH
# success
# trying - departure: ASB, arrival: SIN
# success
# trying - departure: ASB, arrival: ICN
# success
# trying - departure: ASB, arrival: CMB
# success
# trying - departure: ASB, arrival: TPE
# success
# trying - departure: ASB, arrival: DYU
# success
# trying - departure: ASB, arrival: BKK
# success
# trying - departure: ASB, arrival: ESB
# success
# trying - departure: ASB, arrival: AUH
# success
# trying - departure: ASB, arrival: TAS
# success
# trying - departure: ASB, arrival: HAN
# success
#                                                  id  price_amount  \
# 0  9561-2305220330--31734,-30694-1-11431-2305230630      652990.0
# 1  9561-2305220330--31734,-30694-1-11431-2305230630      652990.0
# 2  9561-2305220330--31734,-30694-2-11431-2305222330      826990.0
# 3  9561-2305220330--31734,-30694-2-11431-2305222330      826990.0
# 4  9561-2305220330--31734,-30694-2-11431-2305222330      826990.0
#
#          price_unit                                segment_id  \
# 0  PRICE_UNIT_MILLI   9561-12585-2305220330-2305220540--31734
# 1  PRICE_UNIT_MILLI  12585-11431-2305230330-2305230630--30694
# 2  PRICE_UNIT_MILLI   9561-12585-2305220330-2305220540--31734
# 3  PRICE_UNIT_MILLI  12585-13066-2305220730-2305220900--31734
# 4  PRICE_UNIT_MILLI  13066-11431-2305222020-2305222330--30694
#
#                            transfer_type agent_name  duration_minutes  \
# 0  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               250
# 1  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               120
# 2  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               250
# 3  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip                90
# 4  TRANSFER_TYPE_PROTECTED_SELF_TRANSFER     Mytrip               130
#
#   marketing_flight_number  departure_datetime    arrival_datetime  \
# 0                     323 2023-05-22 03:30:00 2023-05-22 05:40:00
# 1                     476 2023-05-23 03:30:00 2023-05-23 06:30:00
# 2                     323 2023-05-22 03:30:00 2023-05-22 05:40:00
# 3                     269 2023-05-22 07:30:00 2023-05-22 09:00:00
# 4                     534 2023-05-22 20:20:00 2023-05-22 23:30:00
#
#   marketing_carrier_name operating_carrier_name origin_place_name  \
# 0       Turkish Airlines       Turkish Airlines          Ashgabat
# 1         FLYONE Armenia         FLYONE Armenia          Istanbul
# 2       Turkish Airlines       Turkish Airlines          Ashgabat
# 3       Turkish Airlines       Turkish Airlines          Istanbul
# 4         FLYONE Armenia         FLYONE Armenia          Chisinau
#
#   origin_place_iata destination_place_name destination_place_iata  \
# 0               ASB               Istanbul                    IST
# 1               IST                Yerevan                    EVN
# 2               ASB               Istanbul                    IST
# 3               IST               Chisinau                    KIV
# 4               KIV                Yerevan                    EVN
#
#   departure_query arrival_query
# 0             ASB           EVN
# 1             ASB           EVN
# 2             ASB           EVN
# 3             ASB           EVN
# 4             ASB           EVN

# %% [markdown]
# ### Retrieve info that might be missing from first round

# %%
# bring in data
not_in_databasefile_name = '2023-04-26_11-36-55'
not_in_database = pd.read_csv(f'../../Data/FlightAPIData/PendingValues/{not_in_databasefile_name}_pending_values.csv')
display(not_in_database.shape)
display(not_in_database.head())
# Out:
# (584, 2)
#   departure_query arrival_query
# 0             KBL           EVN
# 1             KBL           GYD
# 2             KBL           BAH
# 3             KBL           DAC
# 4             KBL           BWN

# %%
# timestamp so all files have the same time
timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
#timestamp = ''

timestamped_directory = f'../../Data/FlightAPIData/PendingValuesGather/{timestamp}/'
if not os.path.exists(timestamped_directory):
    os.makedirs(timestamped_directory)

time_sleep_sec = 2
year = 2023
month = 5
day = 22


 # init empty list
dataframes = []
counter = 0

for index, row in not_in_database.iterrows():
    departure = row['departure_query']
    arrival = row['arrival_query']
    
    
    # store every 50 iterations
    counter += 1
    if counter % 50 == 0:
        try:
            # concat the dataframes
            combined_dataframe = pd.concat(dataframes, ignore_index=True)
            # save
            combined_dataframe.to_csv(f'../../Data/FlightAPIData/PendingValuesGather/{timestamp}/{timestamp}_last_at_{departure}_{arrival}.csv', index=False)
            print(f'data stored - checkpoint at {departure}-{arrival}')
            
            # re-init empty list
            dataframes = []
            
        except Exception as e:
            print(f"no data to store in this round: {e}")
            
            # re-init empty list
            dataframes = []
            
            continue
        
        
    
    try:
        print(f'trying - departure: {departure}, arrival: {arrival}')
        df = get_flight_data(departure, arrival, year, month, day)
        df['departure_query'] = departure
        df['arrival_query'] = arrival
        dataframes.append(df)
        print('success')
        
            
        # sleep to avoid hitting the api limit
        time.sleep(time_sleep_sec)
    except Exception as e:
        print(f"error while processing {departure}-{arrival}: {e}")
        # sleep to avoid hitting the api limit
        time.sleep(time_sleep_sec)
        continue
    

# store if run if less than 50
# concat the dataframes
combined_dataframe = pd.concat(dataframes, ignore_index=True)
# save
combined_dataframe.to_csv(f'../../Data/FlightAPIData/PendingValuesGather/{timestamp}/{timestamp}_last_at_{departure}_{arrival}.csv', index=False)

# show
display(combined_dataframe.head())
# Out:
# trying - departure: KBL, arrival: EVN
# error while processing KBL-EVN: No itineraries!
# trying - departure: KBL, arrival: GYD
# error while processing KBL-GYD: No itineraries!
# trying - departure: KBL, arrival: BAH
# error while processing KBL-BAH: No itineraries!
# trying - departure: KBL, arrival: DAC
# error while processing KBL-DAC: No itineraries!
# trying - departure: KBL, arrival: BWN
# error while processing KBL-BWN: No itineraries!
# trying - departure: KBL, arrival: PNH
# error while processing KBL-PNH: No itineraries!
# trying - departure: KBL, arrival: PEK
# error while processing KBL-PEK: No itineraries!
# trying - departure: KBL, arrival: LCA
# error while processing KBL-LCA: No itineraries!
# trying - departure: KBL, arrival: DIL
# error while processing KBL-DIL: No itineraries!
# trying - departure: KBL, arrival: TBS
# error while processing KBL-TBS: No itineraries!
# trying - departure: KBL, arrival: CGK
# error while processing KBL-CGK: No itineraries!
# trying - departure: KBL, arrival: TLV
# error while processing KBL-TLV: No itineraries!
# trying - departure: KBL, arrival: NRT
# error while processing KBL-NRT: No itineraries!
# trying - departure: KBL, arrival: NQZ
# error while processing KBL-NQZ: No itineraries!
# trying - departure: KBL, arrival: FRU
# error while processing KBL-FRU: No itineraries!
# trying - departure: KBL, arrival: VTE
# error while processing KBL-VTE: No itineraries!
# trying - departure: KBL, arrival: BEY
# error while processing KBL-BEY: No itineraries!
# trying - departure: KBL, arrival: KUL
# error while processing KBL-KUL: No itineraries!
# trying - departure: KBL, arrival: UBN
# error while processing KBL-UBN: No itineraries!
# trying - departure: KBL, arrival: MCT
# error while processing KBL-MCT: No itineraries!
# trying - departure: KBL, arrival: MNL
# error while processing KBL-MNL: No itineraries!
# trying - departure: KBL, arrival: DOH
# error while processing KBL-DOH: No itineraries!
# trying - departure: KBL, arrival: ICN
# error while processing KBL-ICN: No itineraries!
# trying - departure: KBL, arrival: TPE
# error while processing KBL-TPE: No itineraries!
# trying - departure: KBL, arrival: DYU
# error while processing KBL-DYU: No itineraries!
# trying - departure: KBL, arrival: BKK
# error while processing KBL-BKK: No itineraries!
# trying - departure: KBL, arrival: ESB
# error while processing KBL-ESB: No itineraries!
# trying - departure: KBL, arrival: ASB
# error while processing KBL-ASB: No itineraries!
# trying - departure: KBL, arrival: TAS
# error while processing KBL-TAS: No itineraries!
# trying - departure: KBL, arrival: HAN
# error while processing KBL-HAN: No itineraries!
# trying - departure: GYD, arrival: KBL
# error while processing GYD-KBL: No itineraries!
# trying - departure: BAH, arrival: KBL
# error while processing BAH-KBL: No itineraries!
# trying - departure: DAC, arrival: LCA
# success
# trying - departure: BWN, arrival: KBL
# error while processing BWN-KBL: No itineraries!
# trying - departure: BWN, arrival: LCA
# success
# trying - departure: BWN, arrival: TLV
# success
# trying - departure: PNH, arrival: KBL
# error while processing PNH-KBL: No itineraries!
# trying - departure: PNH, arrival: LCA
# success
# trying - departure: PNH, arrival: TLV
# success
# trying - departure: PEK, arrival: KBL
# error while processing PEK-KBL: No itineraries!
# trying - departure: PEK, arrival: LCA
# success
# trying - departure: LCA, arrival: KBL
# error while processing LCA-KBL: No itineraries!
# trying - departure: DIL, arrival: KBL
# error while processing DIL-KBL: No itineraries!
# trying - departure: DIL, arrival: TLV
# success
# trying - departure: TBS, arrival: KBL
# error while processing TBS-KBL: No itineraries!
# trying - departure: CGK, arrival: KBL
# error while processing CGK-KBL: No itineraries!
# trying - departure: CGK, arrival: TLV
# success
# trying - departure: IKA, arrival: HAN
# success
# trying - departure: BGW, arrival: KBL
# error while processing BGW-KBL: No itineraries!
# data stored - checkpoint at BGW-ESB
# trying - departure: BGW, arrival: ESB
# success
# trying - departure: NRT, arrival: KBL
# error while processing NRT-KBL: No itineraries!
# trying - departure: AMM, arrival: KBL
# error while processing AMM-KBL: No itineraries!
# trying - departure: NQZ, arrival: KBL
# error while processing NQZ-KBL: No itineraries!
# trying - departure: NQZ, arrival: BWN
# success
# trying - departure: NQZ, arrival: PNH
# success
# trying - departure: NQZ, arrival: PEK
# success
# trying - departure: NQZ, arrival: LCA
# success
# trying - departure: NQZ, arrival: DIL
# success
# trying - departure: NQZ, arrival: DEL
# success
# trying - departure: NQZ, arrival: CGK
# success
# trying - departure: NQZ, arrival: NRT
# success
# trying - departure: NQZ, arrival: VTE
# success
# trying - departure: NQZ, arrival: KUL
# success
# trying - departure: NQZ, arrival: MLE
# success
# trying - departure: NQZ, arrival: UBN
# success
# trying - departure: NQZ, arrival: ISB
# success
# trying - departure: NQZ, arrival: MNL
# success
# trying - departure: NQZ, arrival: SIN
# success
# trying - departure: NQZ, arrival: ICN
# success
# trying - departure: NQZ, arrival: TPE
# success
# trying - departure: NQZ, arrival: DYU
# success
# trying - departure: NQZ, arrival: BKK
# success
# trying - departure: NQZ, arrival: ASB
# success
# trying - departure: NQZ, arrival: HAN
# success
# trying - departure: KWI, arrival: KBL
# error while processing KWI-KBL: No itineraries!
# trying - departure: KWI, arrival: BWN
# success
# trying - departure: KWI, arrival: PNH
# success
# trying - departure: KWI, arrival: DIL
# success
# trying - departure: KWI, arrival: NRT
# success
# trying - departure: KWI, arrival: VTE
# success
# trying - departure: KWI, arrival: UBN
# success
# trying - departure: KWI, arrival: SIN
# success
# trying - departure: KWI, arrival: ICN
# success
# trying - departure: KWI, arrival: TPE
# success
# trying - departure: KWI, arrival: DYU
# success
# trying - departure: KWI, arrival: ASB
# success
# trying - departure: KWI, arrival: AUH
# success
# trying - departure: KWI, arrival: HAN
# success
# trying - departure: FRU, arrival: KBL
# error while processing FRU-KBL: No itineraries!
# trying - departure: FRU, arrival: DAC
# success
# trying - departure: FRU, arrival: BWN
# success
# trying - departure: FRU, arrival: PNH
# success
# trying - departure: FRU, arrival: PEK
# success
# trying - departure: FRU, arrival: LCA
# success
# trying - departure: FRU, arrival: DIL
# success
# trying - departure: FRU, arrival: CGK
# success
# trying - departure: FRU, arrival: NRT
# success
# trying - departure: FRU, arrival: NQZ
# success
# trying - departure: FRU, arrival: VTE
# success
# data stored - checkpoint at FRU-KUL
# trying - departure: FRU, arrival: KUL
# success
# trying - departure: FRU, arrival: MLE
# success
# trying - departure: FRU, arrival: KTM
# success
# trying - departure: FRU, arrival: ISB
# success
# trying - departure: FRU, arrival: MNL
# success
# trying - departure: FRU, arrival: SIN
# success
# trying - departure: FRU, arrival: CMB
# success
# trying - departure: FRU, arrival: TPE
# success
# trying - departure: FRU, arrival: DYU
# success
# trying - departure: FRU, arrival: BKK
# success
# trying - departure: FRU, arrival: ESB
# success
# trying - departure: FRU, arrival: ASB
# success
# trying - departure: FRU, arrival: TAS
# success
# trying - departure: FRU, arrival: HAN
# success
# trying - departure: VTE, arrival: KBL
# error while processing VTE-KBL: No itineraries!
# trying - departure: VTE, arrival: EVN
# success
# trying - departure: VTE, arrival: GYD
# success
# trying - departure: VTE, arrival: BAH
# success
# trying - departure: VTE, arrival: DAC
# success
# trying - departure: VTE, arrival: BWN
# success
# trying - departure: VTE, arrival: PEK
# success
# trying - departure: VTE, arrival: LCA
# success
# trying - departure: VTE, arrival: DIL
# success
# trying - departure: VTE, arrival: TBS
# success
# trying - departure: VTE, arrival: DEL
# success
# trying - departure: VTE, arrival: IKA
# success
# trying - departure: VTE, arrival: BGW
# success
# trying - departure: VTE, arrival: TLV
# success
# trying - departure: VTE, arrival: AMM
# success
# trying - departure: VTE, arrival: NQZ
# success
# trying - departure: VTE, arrival: KWI
# success
# trying - departure: VTE, arrival: FRU
# success
# trying - departure: VTE, arrival: BEY
# success
# trying - departure: VTE, arrival: MLE
# success
# trying - departure: VTE, arrival: UBN
# success
# trying - departure: VTE, arrival: KTM
# success
# trying - departure: VTE, arrival: MCT
# success
# trying - departure: VTE, arrival: ISB
# success
# trying - departure: VTE, arrival: DOH
# success
# trying - departure: VTE, arrival: RUH
# success
# trying - departure: VTE, arrival: CMB
# success
# trying - departure: VTE, arrival: DYU
# success
# trying - departure: VTE, arrival: ESB
# success
# trying - departure: VTE, arrival: ASB
# success
# trying - departure: VTE, arrival: AUH
# success
# trying - departure: VTE, arrival: TAS
# success
# trying - departure: BEY, arrival: KBL
# error while processing BEY-KBL: No itineraries!
# trying - departure: BEY, arrival: BAH
# success
# trying - departure: BEY, arrival: DAC
# success
# trying - departure: BEY, arrival: BWN
# success
# data stored - checkpoint at BEY-PNH
# trying - departure: BEY, arrival: PNH
# success
# trying - departure: BEY, arrival: PEK
# success
# trying - departure: BEY, arrival: DIL
# success
# trying - departure: BEY, arrival: DEL
# success
# trying - departure: BEY, arrival: CGK
# success
# trying - departure: BEY, arrival: NRT
# success
# trying - departure: BEY, arrival: NQZ
# success
# trying - departure: BEY, arrival: VTE
# success
# trying - departure: BEY, arrival: KUL
# success
# trying - departure: BEY, arrival: MLE
# success
# trying - departure: BEY, arrival: UBN
# success
# trying - departure: BEY, arrival: KTM
# success
# trying - departure: BEY, arrival: ISB
# success
# trying - departure: BEY, arrival: MNL
# success
# trying - departure: BEY, arrival: SIN
# success
# trying - departure: BEY, arrival: ICN
# success
# trying - departure: BEY, arrival: TPE
# success
# trying - departure: BEY, arrival: DYU
# success
# trying - departure: BEY, arrival: BKK
# success
# trying - departure: BEY, arrival: ASB
# success
# trying - departure: BEY, arrival: HAN
# success
# trying - departure: KUL, arrival: KBL
# success
# trying - departure: KUL, arrival: EVN
# success
# trying - departure: KUL, arrival: BAH
# success
# trying - departure: KUL, arrival: LCA
# success
# trying - departure: KUL, arrival: DIL
# success
# trying - departure: KUL, arrival: TBS
# success
# trying - departure: KUL, arrival: IKA
# success
# trying - departure: KUL, arrival: BGW
# success
# trying - departure: KUL, arrival: TLV
# success
# trying - departure: KUL, arrival: KWI
# success
# trying - departure: KUL, arrival: FRU
# success
# trying - departure: KUL, arrival: BEY
# success
# trying - departure: KUL, arrival: UBN
# success
# trying - departure: KUL, arrival: KTM
# success
# trying - departure: KUL, arrival: MCT
# success
# trying - departure: KUL, arrival: DOH
# success
# trying - departure: KUL, arrival: CMB
# success
# trying - departure: KUL, arrival: DYU
# success
# trying - departure: KUL, arrival: ASB
# success
# trying - departure: MLE, arrival: KBL
# error while processing MLE-KBL: No itineraries!
# trying - departure: MLE, arrival: EVN
# success
# trying - departure: MLE, arrival: BWN
# success
# trying - departure: MLE, arrival: PNH
# success
# trying - departure: MLE, arrival: PEK
# success
# trying - departure: MLE, arrival: LCA
# success
# trying - departure: MLE, arrival: DIL
# success
# trying - departure: MLE, arrival: TBS
# success
# trying - departure: MLE, arrival: CGK
# success
# trying - departure: MLE, arrival: IKA
# success
# data stored - checkpoint at MLE-NRT
# trying - departure: MLE, arrival: NRT
# success
# trying - departure: MLE, arrival: NQZ
# success
# trying - departure: MLE, arrival: VTE
# success
# trying - departure: MLE, arrival: UBN
# success
# trying - departure: MLE, arrival: ISB
# success
# trying - departure: MLE, arrival: MNL
# success
# trying - departure: MLE, arrival: DOH
# success
# trying - departure: MLE, arrival: ICN
# success
# trying - departure: MLE, arrival: TPE
# success
# trying - departure: MLE, arrival: DYU
# success
# trying - departure: MLE, arrival: ESB
# success
# trying - departure: MLE, arrival: ASB
# success
# trying - departure: MLE, arrival: HAN
# success
# trying - departure: UBN, arrival: KBL
# error while processing UBN-KBL: No itineraries!
# trying - departure: UBN, arrival: DIL
# error while processing UBN-DIL: No itineraries!
# trying - departure: KTM, arrival: KBL
# error while processing KTM-KBL: No itineraries!
# trying - departure: KTM, arrival: EVN
# success
# trying - departure: KTM, arrival: BWN
# success
# trying - departure: KTM, arrival: PEK
# success
# trying - departure: KTM, arrival: LCA
# success
# trying - departure: KTM, arrival: DIL
# success
# trying - departure: KTM, arrival: IKA
# success
# trying - departure: KTM, arrival: AMM
# success
# trying - departure: KTM, arrival: NQZ
# success
# trying - departure: KTM, arrival: VTE
# success
# trying - departure: KTM, arrival: UBN
# success
# trying - departure: KTM, arrival: ISB
# success
# trying - departure: KTM, arrival: DYU
# success
# trying - departure: KTM, arrival: ESB
# success
# trying - departure: KTM, arrival: ASB
# success
# trying - departure: KTM, arrival: AUH
# success
# trying - departure: KTM, arrival: HAN
# success
# trying - departure: MCT, arrival: KBL
# success
# trying - departure: MCT, arrival: BWN
# success
# trying - departure: MCT, arrival: PNH
# success
# trying - departure: MCT, arrival: PEK
# success
# trying - departure: MCT, arrival: LCA
# success
# trying - departure: MCT, arrival: DIL
# success
# trying - departure: MCT, arrival: VTE
# success
# trying - departure: MCT, arrival: UBN
# success
# trying - departure: MCT, arrival: ISB
# success
# trying - departure: MCT, arrival: DOH
# success
# trying - departure: MCT, arrival: SIN
# success
# trying - departure: MCT, arrival: ICN
# success
# trying - departure: MCT, arrival: TPE
# success
# trying - departure: MCT, arrival: DYU
# success
# trying - departure: MCT, arrival: BKK
# success
# trying - departure: MCT, arrival: ASB
# success
# trying - departure: MCT, arrival: AUH
# success
# trying - departure: MCT, arrival: HAN
# success
# data stored - checkpoint at ISB-KBL
# trying - departure: ISB, arrival: KBL
# success
# trying - departure: ISB, arrival: EVN
# success
# trying - departure: ISB, arrival: GYD
# success
# trying - departure: ISB, arrival: DAC
# success
# trying - departure: ISB, arrival: BWN
# success
# trying - departure: ISB, arrival: PNH
# success
# trying - departure: ISB, arrival: PEK
# success
# trying - departure: ISB, arrival: LCA
# success
# trying - departure: ISB, arrival: DIL
# success
# trying - departure: ISB, arrival: TBS
# success
# trying - departure: ISB, arrival: DEL
# success
# trying - departure: ISB, arrival: CGK
# success
# trying - departure: ISB, arrival: IKA
# success
# trying - departure: ISB, arrival: BGW
# success
# trying - departure: ISB, arrival: TLV
# success
# trying - departure: ISB, arrival: NRT
# success
# trying - departure: ISB, arrival: AMM
# success
# trying - departure: ISB, arrival: NQZ
# success
# trying - departure: ISB, arrival: KWI
# success
# trying - departure: ISB, arrival: FRU
# success
# trying - departure: ISB, arrival: VTE
# success
# trying - departure: ISB, arrival: BEY
# success
# trying - departure: ISB, arrival: MLE
# success
# trying - departure: ISB, arrival: UBN
# success
# trying - departure: ISB, arrival: MNL
# success
# trying - departure: ISB, arrival: SIN
# success
# trying - departure: ISB, arrival: ICN
# success
# trying - departure: ISB, arrival: CMB
# success
# trying - departure: ISB, arrival: TPE
# success
# trying - departure: ISB, arrival: DYU
# success
# trying - departure: ISB, arrival: BKK
# success
# trying - departure: ISB, arrival: ESB
# success
# trying - departure: ISB, arrival: ASB
# success
# trying - departure: ISB, arrival: TAS
# success
# trying - departure: ISB, arrival: HAN
# success
# trying - departure: MNL, arrival: KBL
# error while processing MNL-KBL: No itineraries!
# trying - departure: MNL, arrival: EVN
# success
# trying - departure: MNL, arrival: GYD
# success
# trying - departure: MNL, arrival: BAH
# success
# trying - departure: MNL, arrival: DAC
# success
# trying - departure: MNL, arrival: PEK
# success
# trying - departure: MNL, arrival: LCA
# success
# trying - departure: MNL, arrival: DIL
# success
# trying - departure: MNL, arrival: TBS
# success
# trying - departure: MNL, arrival: IKA
# success
# trying - departure: MNL, arrival: BGW
# success
# trying - departure: MNL, arrival: NQZ
# success
# trying - departure: MNL, arrival: FRU
# success
# trying - departure: MNL, arrival: BEY
# success
# trying - departure: MNL, arrival: MLE
# success
# data stored - checkpoint at MNL-UBN
# trying - departure: MNL, arrival: UBN
# success
# trying - departure: MNL, arrival: KTM
# success
# trying - departure: MNL, arrival: MCT
# success
# trying - departure: MNL, arrival: ISB
# success
# trying - departure: MNL, arrival: DOH
# success
# trying - departure: MNL, arrival: RUH
# success
# trying - departure: MNL, arrival: DYU
# success
# trying - departure: MNL, arrival: ESB
# success
# trying - departure: MNL, arrival: ASB
# success
# trying - departure: MNL, arrival: AUH
# success
# trying - departure: MNL, arrival: TAS
# success
# trying - departure: DOH, arrival: KBL
# error while processing DOH-KBL: No itineraries!
# trying - departure: DOH, arrival: BAH
# success
# trying - departure: DOH, arrival: DAC
# success
# trying - departure: DOH, arrival: BWN
# success
# trying - departure: DOH, arrival: PNH
# success
# trying - departure: DOH, arrival: PEK
# success
# trying - departure: DOH, arrival: DIL
# success
# trying - departure: DOH, arrival: CGK
# success
# trying - departure: DOH, arrival: NRT
# success
# trying - departure: DOH, arrival: NQZ
# success
# trying - departure: DOH, arrival: VTE
# success
# trying - departure: DOH, arrival: KUL
# success
# trying - departure: DOH, arrival: MLE
# success
# trying - departure: DOH, arrival: UBN
# success
# trying - departure: DOH, arrival: ISB
# success
# trying - departure: DOH, arrival: MNL
# success
# trying - departure: DOH, arrival: SIN
# success
# trying - departure: DOH, arrival: CMB
# success
# trying - departure: DOH, arrival: TPE
# success
# trying - departure: DOH, arrival: DYU
# success
# trying - departure: DOH, arrival: BKK
# success
# trying - departure: DOH, arrival: ASB
# success
# trying - departure: DOH, arrival: TAS
# success
# trying - departure: RUH, arrival: KBL
# success
# trying - departure: RUH, arrival: BWN
# success
# trying - departure: RUH, arrival: PNH
# success
# trying - departure: RUH, arrival: PEK
# success
# trying - departure: RUH, arrival: DIL
# success
# trying - departure: RUH, arrival: CGK
# success
# trying - departure: RUH, arrival: NRT
# success
# trying - departure: RUH, arrival: VTE
# success
# trying - departure: RUH, arrival: KUL
# success
# trying - departure: RUH, arrival: UBN
# success
# trying - departure: RUH, arrival: SIN
# success
# trying - departure: RUH, arrival: ICN
# success
# trying - departure: RUH, arrival: TPE
# success
# trying - departure: RUH, arrival: DYU
# success
# trying - departure: RUH, arrival: ASB
# success
# trying - departure: RUH, arrival: AUH
# success
# data stored - checkpoint at RUH-HAN
# trying - departure: RUH, arrival: HAN
# success
# trying - departure: SIN, arrival: KBL
# success
# trying - departure: SIN, arrival: EVN
# success
# trying - departure: SIN, arrival: GYD
# success
# trying - departure: SIN, arrival: BAH
# success
# trying - departure: SIN, arrival: LCA
# success
# trying - departure: SIN, arrival: DIL
# success
# trying - departure: SIN, arrival: TBS
# success
# trying - departure: SIN, arrival: IKA
# success
# trying - departure: SIN, arrival: BGW
# success
# trying - departure: SIN, arrival: TLV
# success
# trying - departure: SIN, arrival: AMM
# success
# trying - departure: SIN, arrival: NQZ
# success
# trying - departure: SIN, arrival: KWI
# success
# trying - departure: SIN, arrival: FRU
# success
# trying - departure: SIN, arrival: BEY
# success
# trying - departure: SIN, arrival: UBN
# success
# trying - departure: SIN, arrival: KTM
# success
# trying - departure: SIN, arrival: MCT
# success
# trying - departure: SIN, arrival: ISB
# success
# trying - departure: SIN, arrival: DOH
# success
# trying - departure: SIN, arrival: RUH
# success
# trying - departure: SIN, arrival: DYU
# success
# trying - departure: SIN, arrival: ESB
# success
# trying - departure: SIN, arrival: ASB
# success
# trying - departure: SIN, arrival: TAS
# success
# trying - departure: ICN, arrival: KBL
# error while processing ICN-KBL: No itineraries!
# trying - departure: ICN, arrival: EVN
# success
# trying - departure: ICN, arrival: GYD
# success
# trying - departure: ICN, arrival: BAH
# success
# trying - departure: ICN, arrival: BWN
# success
# trying - departure: ICN, arrival: LCA
# success
# trying - departure: ICN, arrival: DIL
# success
# trying - departure: ICN, arrival: TBS
# success
# trying - departure: ICN, arrival: IKA
# success
# trying - departure: ICN, arrival: BGW
# success
# trying - departure: ICN, arrival: TLV
# success
# trying - departure: ICN, arrival: AMM
# error while processing ICN-AMM: No itineraries!
# trying - departure: ICN, arrival: NQZ
# error while processing ICN-NQZ: No itineraries!
# trying - departure: ICN, arrival: KWI
# success
# trying - departure: ICN, arrival: FRU
# error while processing ICN-FRU: No itineraries!
# trying - departure: ICN, arrival: VTE
# success
# trying - departure: ICN, arrival: BEY
# success
# trying - departure: ICN, arrival: MLE
# success
# trying - departure: ICN, arrival: KTM
# error while processing ICN-KTM: No itineraries!
# trying - departure: ICN, arrival: MCT
# error while processing ICN-MCT: No itineraries!
# trying - departure: ICN, arrival: ISB
# success
# trying - departure: ICN, arrival: DOH
# success
# trying - departure: ICN, arrival: RUH
# success
# trying - departure: ICN, arrival: SIN
# success
# data stored - checkpoint at ICN-DYU
# trying - departure: ICN, arrival: DYU
# success
# trying - departure: ICN, arrival: ESB
# success
# trying - departure: ICN, arrival: ASB
# success
# trying - departure: ICN, arrival: TAS
# success
# trying - departure: CMB, arrival: KBL
# error while processing CMB-KBL: No itineraries!
# trying - departure: CMB, arrival: EVN
# error while processing CMB-EVN: No itineraries!
# trying - departure: CMB, arrival: GYD
# success
# trying - departure: CMB, arrival: BAH
# success
# trying - departure: CMB, arrival: DAC
# success
# trying - departure: CMB, arrival: BWN
# success
# trying - departure: CMB, arrival: PNH
# error while processing CMB-PNH: No itineraries!
# trying - departure: CMB, arrival: PEK
# success
# trying - departure: CMB, arrival: LCA
# success
# trying - departure: CMB, arrival: DIL
# success
# trying - departure: CMB, arrival: TBS
# error while processing CMB-TBS: No itineraries!
# trying - departure: CMB, arrival: IKA
# error while processing CMB-IKA: No itineraries!
# trying - departure: CMB, arrival: BGW
# success
# trying - departure: CMB, arrival: TLV
# success
# trying - departure: CMB, arrival: AMM
# success
# trying - departure: CMB, arrival: NQZ
# success
# trying - departure: CMB, arrival: FRU
# success
# trying - departure: CMB, arrival: VTE
# success
# trying - departure: CMB, arrival: BEY
# success
# trying - departure: CMB, arrival: UBN
# success
# trying - departure: CMB, arrival: MCT
# success
# trying - departure: CMB, arrival: ISB
# error while processing CMB-ISB: No itineraries!
# trying - departure: CMB, arrival: MNL
# success
# trying - departure: CMB, arrival: DOH
# success
# trying - departure: CMB, arrival: RUH
# success
# trying - departure: CMB, arrival: SIN
# success
# trying - departure: CMB, arrival: TPE
# error while processing CMB-TPE: No itineraries!
# trying - departure: CMB, arrival: DYU
# error while processing CMB-DYU: No itineraries!
# trying - departure: CMB, arrival: BKK
# success
# trying - departure: CMB, arrival: ESB
# success
# trying - departure: CMB, arrival: ASB
# error while processing CMB-ASB: No itineraries!
# trying - departure: CMB, arrival: AUH
# success
# trying - departure: CMB, arrival: TAS
# error while processing CMB-TAS: No itineraries!
# trying - departure: CMB, arrival: HAN
# success
# trying - departure: TPE, arrival: KBL
# error while processing TPE-KBL: No itineraries!
# trying - departure: TPE, arrival: EVN
# success
# trying - departure: TPE, arrival: GYD
# success
# trying - departure: TPE, arrival: BAH
# success
# trying - departure: TPE, arrival: DAC
# success
# trying - departure: TPE, arrival: BWN
# success
# trying - departure: TPE, arrival: LCA
# success
# trying - departure: TPE, arrival: DIL
# success
# trying - departure: TPE, arrival: TBS
# success
# trying - departure: TPE, arrival: IKA
# success
# trying - departure: TPE, arrival: BGW
# success
# trying - departure: TPE, arrival: NQZ
# success
# data stored - checkpoint at TPE-KWI
# trying - departure: TPE, arrival: KWI
# success
# trying - departure: TPE, arrival: FRU
# success
# trying - departure: TPE, arrival: BEY
# success
# trying - departure: TPE, arrival: MLE
# success
# trying - departure: TPE, arrival: MCT
# success
# trying - departure: TPE, arrival: ISB
# success
# trying - departure: TPE, arrival: DOH
# success
# trying - departure: TPE, arrival: RUH
# success
# trying - departure: TPE, arrival: CMB
# success
# trying - departure: TPE, arrival: DYU
# success
# trying - departure: TPE, arrival: ESB
# success
# trying - departure: TPE, arrival: ASB
# success
# trying - departure: TPE, arrival: TAS
# success
# trying - departure: DYU, arrival: KBL
# error while processing DYU-KBL: No itineraries!
# trying - departure: DYU, arrival: EVN
# success
# trying - departure: DYU, arrival: BWN
# success
# trying - departure: DYU, arrival: PNH
# success
# trying - departure: DYU, arrival: PEK
# success
# trying - departure: DYU, arrival: LCA
# success
# trying - departure: DYU, arrival: DIL
# error while processing DYU-DIL: No itineraries!
# trying - departure: DYU, arrival: CGK
# success
# trying - departure: DYU, arrival: NRT
# success
# trying - departure: DYU, arrival: VTE
# success
# trying - departure: DYU, arrival: KUL
# success
# trying - departure: DYU, arrival: UBN
# success
# trying - departure: DYU, arrival: ISB
# success
# trying - departure: DYU, arrival: MNL
# success
# trying - departure: DYU, arrival: DOH
# success
# trying - departure: DYU, arrival: SIN
# success
# trying - departure: DYU, arrival: ICN
# success
# trying - departure: DYU, arrival: TPE
# success
# trying - departure: DYU, arrival: BKK
# success
# trying - departure: DYU, arrival: ESB
# success
# trying - departure: DYU, arrival: ASB
# success
# trying - departure: DYU, arrival: AUH
# success
# trying - departure: DYU, arrival: HAN
# success
# trying - departure: BKK, arrival: KBL
# success
# trying - departure: BKK, arrival: GYD
# success
# trying - departure: BKK, arrival: BAH
# success
# trying - departure: BKK, arrival: BWN
# success
# trying - departure: BKK, arrival: LCA
# success
# trying - departure: BKK, arrival: DIL
# success
# trying - departure: BKK, arrival: BGW
# success
# trying - departure: BKK, arrival: NQZ
# success
# trying - departure: BKK, arrival: KWI
# success
# trying - departure: BKK, arrival: FRU
# success
# trying - departure: BKK, arrival: BEY
# success
# trying - departure: BKK, arrival: UBN
# success
# trying - departure: BKK, arrival: RUH
# success
# trying - departure: BKK, arrival: DYU
# success
# data stored - checkpoint at BKK-ESB
# trying - departure: BKK, arrival: ESB
# success
# trying - departure: BKK, arrival: ASB
# success
# trying - departure: BKK, arrival: TAS
# success
# trying - departure: ESB, arrival: KBL
# error while processing ESB-KBL: No itineraries!
# trying - departure: ESB, arrival: DAC
# success
# trying - departure: ESB, arrival: BWN
# success
# trying - departure: ESB, arrival: PNH
# success
# trying - departure: ESB, arrival: PEK
# success
# trying - departure: ESB, arrival: LCA
# success
# trying - departure: ESB, arrival: DIL
# success
# trying - departure: ESB, arrival: DEL
# success
# trying - departure: ESB, arrival: CGK
# success
# trying - departure: ESB, arrival: NRT
# success
# trying - departure: ESB, arrival: VTE
# success
# trying - departure: ESB, arrival: KUL
# success
# trying - departure: ESB, arrival: MLE
# success
# trying - departure: ESB, arrival: UBN
# success
# trying - departure: ESB, arrival: KTM
# success
# trying - departure: ESB, arrival: ISB
# success
# trying - departure: ESB, arrival: MNL
# success
# trying - departure: ESB, arrival: SIN
# success
# trying - departure: ESB, arrival: ICN
# success
# trying - departure: ESB, arrival: CMB
# success
# trying - departure: ESB, arrival: TPE
# success
# trying - departure: ESB, arrival: DYU
# success
# trying - departure: ESB, arrival: ASB
# success
# trying - departure: ESB, arrival: HAN
# success
# trying - departure: ASB, arrival: KBL
# error while processing ASB-KBL: No itineraries!
# trying - departure: AUH, arrival: KBL
# success
# trying - departure: AUH, arrival: BWN
# success
# trying - departure: AUH, arrival: PNH
# success
# trying - departure: AUH, arrival: PEK
# success
# trying - departure: AUH, arrival: DIL
# success
# trying - departure: AUH, arrival: CGK
# success
# trying - departure: AUH, arrival: BGW
# success
# trying - departure: AUH, arrival: VTE
# success
# trying - departure: AUH, arrival: UBN
# success
# trying - departure: AUH, arrival: MNL
# success
# trying - departure: AUH, arrival: SIN
# success
# trying - departure: AUH, arrival: TPE
# success
# trying - departure: AUH, arrival: DYU
# success
# trying - departure: AUH, arrival: ASB
# success
# trying - departure: TAS, arrival: KBL
# success
# trying - departure: TAS, arrival: BWN
# success
# trying - departure: TAS, arrival: PNH
# success
# trying - departure: TAS, arrival: LCA
# success
# trying - departure: TAS, arrival: DIL
# error while processing TAS-DIL: No itineraries!
# trying - departure: TAS, arrival: CGK
# success
# trying - departure: TAS, arrival: VTE
# success
# trying - departure: TAS, arrival: UBN
# success
# data stored - checkpoint at TAS-ISB
# trying - departure: TAS, arrival: ISB
# success
# trying - departure: TAS, arrival: MNL
# success
# trying - departure: TAS, arrival: SIN
# success
# trying - departure: TAS, arrival: ICN
# success
# trying - departure: TAS, arrival: TPE
# success
# trying - departure: TAS, arrival: DYU
# success
# trying - departure: TAS, arrival: BKK
# success
# trying - departure: TAS, arrival: ASB
# success
# trying - departure: TAS, arrival: HAN
# success
# trying - departure: HAN, arrival: KBL
# error while processing HAN-KBL: No itineraries!
# trying - departure: HAN, arrival: EVN
# success
# trying - departure: HAN, arrival: GYD
# success
# trying - departure: HAN, arrival: BAH
# success
# trying - departure: HAN, arrival: DAC
# success
# trying - departure: HAN, arrival: BWN
# success
# trying - departure: HAN, arrival: PEK
# success
# trying - departure: HAN, arrival: LCA
# success
# trying - departure: HAN, arrival: DIL
# success
# trying - departure: HAN, arrival: TBS
# success
# trying - departure: HAN, arrival: IKA
# success
# trying - departure: HAN, arrival: BGW
# success
# trying - departure: HAN, arrival: TLV
# success
# trying - departure: HAN, arrival: AMM
# success
# trying - departure: HAN, arrival: NQZ
# success
# trying - departure: HAN, arrival: KWI
# success
# trying - departure: HAN, arrival: FRU
# success
# trying - departure: HAN, arrival: BEY
# success
# trying - departure: HAN, arrival: MLE
# success
# trying - departure: HAN, arrival: UBN
# success
# trying - departure: HAN, arrival: KTM
# success
# trying - departure: HAN, arrival: MCT
# success
# trying - departure: HAN, arrival: ISB
# success
# trying - departure: HAN, arrival: RUH
# success
# trying - departure: HAN, arrival: CMB
# success
# trying - departure: HAN, arrival: DYU
# success
#                                                   id  price_amount  \
# 0  16759-2305220200--32532,-32301,-31963-2-12569-...      605700.0
# 1  16759-2305220200--32532,-32301,-31963-2-12569-...      605700.0
# 2  16759-2305220200--32532,-32301,-31963-2-12569-...      605700.0
# 3         16759-2305220235--31734-1-12569-2305230335      697700.0
# 4         16759-2305220235--31734-1-12569-2305230335      697700.0
#
#          price_unit                                segment_id  \
# 0  PRICE_UNIT_MILLI  16759-12042-2305220200-2305220350--32532
# 1  PRICE_UNIT_MILLI  12042-11182-2305221155-2305221450--32301
# 2  PRICE_UNIT_MILLI  11182-12569-2305230415-2305230815--31963
# 3  PRICE_UNIT_MILLI  16759-12585-2305220235-2305220550--31734
# 4  PRICE_UNIT_MILLI  12585-12569-2305222015-2305230335--31734
#
#            transfer_type        agent_name  duration_minutes  \
# 0  TRANSFER_TYPE_MANAGED          Trip.com               170
# 1  TRANSFER_TYPE_MANAGED          Trip.com               175
# 2  TRANSFER_TYPE_MANAGED          Trip.com               180
# 3  TRANSFER_TYPE_MANAGED  Turkish Airlines               315
# 4  TRANSFER_TYPE_MANAGED  Turkish Airlines               320
#
#   marketing_flight_number  departure_datetime    arrival_datetime  \
# 0                    5032 2023-05-22 02:00:00 2023-05-22 03:50:00
# 1                     710 2023-05-22 11:55:00 2023-05-22 14:50:00
# 2                     234 2023-05-23 04:15:00 2023-05-23 08:15:00
# 3                     371 2023-05-22 02:35:00 2023-05-22 05:50:00
# 4                     710 2023-05-22 20:15:00 2023-05-23 03:35:00
#
#   marketing_carrier_name operating_carrier_name  \
# 0    Azerbaijan Airlines    Azerbaijan Airlines
# 1               flydubai               flydubai
# 2                    PIA                    PIA
# 3       Turkish Airlines       Turkish Airlines
# 4       Turkish Airlines       Turkish Airlines
#
#                   origin_place_name origin_place_iata  \
# 0                          Tashkent               TAS
# 1  Baku Heydar Aliyev International               GYD
# 2                             Dubai               DXB
# 3                          Tashkent               TAS
# 4                          Istanbul               IST
#
#              destination_place_name destination_place_iata departure_query  \
# 0  Baku Heydar Aliyev International                    GYD             TAS
# 1                             Dubai                    DXB             TAS
# 2                         Islamabad                    ISB             TAS
# 3                          Istanbul                    IST             TAS
# 4                         Islamabad                    ISB             TAS
#
#   arrival_query
# 0           ISB
# 1           ISB
# 2           ISB
# 3           ISB
# 4           ISB
